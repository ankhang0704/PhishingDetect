# %% [markdown]
# <a href="https://colab.research.google.com/github/MrDev333/PhishingDetect/blob/main/tool/awskeybreaker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Tạo tool giải mã và xóa AWS Secret Access Key khỏi một file

# %% [markdown]
# ## Xác định định dạng và loại file
#
# ### Subtask:
# Công cụ cần nhận diện các loại file phổ biến (ví dụ: `.env`, `.yml`, `.json`, `.txt`, mã nguồn Python/Java/Node.js, v.v.) và các định dạng mà AWS Secret Access Key có thể xuất hiện trong đó (ví dụ: biến môi trường, trường trong JSON/YAML, giá trị trong file cấu hình key=value, v.v.).

# %% [markdown]
# **Reasoning**:
# Define the list of common file extensions and the potential formats for AWS Secret Access Keys within those file types, as requested by the instructions.

# %%
file_formats = {
    ".env": ["KEY=VALUE"],
    ".yml": ["key: value"],
    ".yaml": ["key: value"],
    ".json": ['"key": "value"'],
    ".txt": ["KEY=VALUE", '"key": "value"', "key: value", "plain_text"],
    ".py": ["KEY = 'VALUE'", 'KEY = "VALUE"'],
    ".java": ["String KEY = \"VALUE\";"],
    ".js": ["const KEY = 'VALUE';", "let KEY = 'VALUE';", "var KEY = 'VALUE';"],
    ".sh": ["export KEY=VALUE"]
}

print("Common file extensions and potential AWS Secret Access Key formats:")
for ext, formats in file_formats.items():
    print(f"File extension: {ext}")
    print(f"Potential formats: {', '.join(formats)}")
# Out:
# Common file extensions and potential AWS Secret Access Key formats:
# File extension: .env
# Potential formats: KEY=VALUE
# File extension: .yml
# Potential formats: key: value
# File extension: .yaml
# Potential formats: key: value
# File extension: .json
# Potential formats: "key": "value"
# File extension: .txt
# Potential formats: KEY=VALUE, "key": "value", key: value, plain_text
# File extension: .py
# Potential formats: KEY = 'VALUE', KEY = "VALUE"
# File extension: .java
# Potential formats: String KEY = "VALUE";
# File extension: .js
# Potential formats: const KEY = 'VALUE';, let KEY = 'VALUE';, var KEY = 'VALUE';
# File extension: .sh
# Potential formats: export KEY=VALUE

# %% [markdown]
# ## Phân tích nội dung file
#
# ### Subtask:
# Đọc và phân tích nội dung file để tìm kiếm các chuỗi có thể là AWS Secret Access Key. Cần sử dụng các biểu thức chính quy (regular expressions) để nhận diện pattern của AWS Access Key ID (bắt đầu bằng "AKIA") và AWS Secret Access Key.

# %% [markdown]
# **Reasoning**:
# Import the `re` module and define the regular expressions for AWS Access Key ID and Secret Access Key.

# %%
import re

# Regular expression for AWS Access Key ID (starts with "AKIA" followed by 16 uppercase letters or digits)
aws_access_key_id_pattern = re.compile(r'AKIA[0-9A-Z]{16}')

# Regular expression for AWS Secret Access Key (40 characters consisting of uppercase letters, lowercase letters, digits, '+', '/')
aws_secret_access_key_pattern = re.compile(r'[0-9a-zA-Z+/]{40}')

print("Regular expressions for AWS Access Key ID and Secret Access Key defined.")
# Out:
# Regular expressions for AWS Access Key ID and Secret Access Key defined.

# %% [markdown]
# **Reasoning**:
# Create a function to read the file content, search for the defined patterns, and return the potential matches with their locations.

# %%
def find_aws_keys_in_file(file_path):
    """
    Reads a file and searches for potential AWS Access Key IDs and Secret Access Keys.

    Args:
        file_path: The path to the file to scan.

    Returns:
        A list of dictionaries, where each dictionary represents a potential match
        and contains the line number, the matched string, and the key type
        ('Access Key ID' or 'Secret Access Key').
    """
    potential_matches = []
    try:
        with open(file_path, 'r') as f:
            for line_num, line in enumerate(f, 1):
                # Search for Access Key IDs
                access_key_matches = aws_access_key_id_pattern.findall(line)
                for match in access_key_matches:
                    potential_matches.append({
                        'line_number': line_num,
                        'matched_string': match,
                        'key_type': 'Access Key ID'
                    })

                # Search for Secret Access Keys
                secret_key_matches = aws_secret_access_key_pattern.findall(line)
                for match in secret_key_matches:
                    potential_matches.append({
                        'line_number': line_num,
                        'matched_string': match,
                        'key_type': 'Secret Access Key'
                    })
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
    except Exception as e:
        print(f"An error occurred while reading the file: {e}")

    return potential_matches

print("Function find_aws_keys_in_file defined.")
# Out:
# Function find_aws_keys_in_file defined.

# %% [markdown]
# ## Xử lý các định dạng encoding
#
# ### Subtask:
# Nếu key được lưu dưới dạng base64, URL encoded, hoặc các định dạng khác, công cụ cần có khả năng giải mã chúng về dạng gốc trước khi xử lý. Tuy nhiên, như đã nói ở trên, Secret Access Key bản thân nó không phải là dữ liệu mã hóa cần giải mã theo nghĩa thông thường. Có thể đây là bước bạn muốn xử lý các trường hợp key được nhúng trong chuỗi phức tạp.

# %% [markdown]
# **Reasoning**:
# Import necessary libraries for decoding potential key strings.

# %%
import base64
import urllib.parse

# %% [markdown]
# **Reasoning**:
# Define a function to decode potential key strings using base64 and URL decoding, and handle exceptions.

# %%
def decode_potential_key(potential_key_string):
    """
    Attempts to decode a potential key string using base64 and URL decoding.

    Args:
        potential_key_string: The string that might be encoded.

    Returns:
        The decoded string if decoding is successful, otherwise the original string.
    """
    decoded_string = potential_key_string

    # Try Base64 decoding
    try:
        decoded_bytes = base64.b64decode(potential_key_string)
        # Check if the decoded bytes can be decoded to a UTF-8 string
        try:
            base64_decoded = decoded_bytes.decode('utf-8')
            # A basic check if the base64 decoded string might be a valid key pattern
            # (optional, adjust pattern as needed)
            if re.fullmatch(aws_secret_access_key_pattern, base64_decoded):
                 decoded_string = base64_decoded
        except UnicodeDecodeError:
            pass # Not a valid UTF-8 string after base64 decode

    except (base64.binascii.Error, TypeError):
        pass # Not valid base64

    # Try URL decoding (only if not successfully base64 decoded)
    if decoded_string == potential_key_string:
        url_decoded = urllib.parse.unquote(potential_key_string)
        # A basic check if the URL decoded string might be a valid key pattern
        # (optional, adjust pattern as needed)
        if re.fullmatch(aws_secret_access_key_pattern, url_decoded):
             decoded_string = url_decoded


    return decoded_string

# %% [markdown]
# ## Xóa hoặc thay thế key
#
# ### Subtask:
# Sau khi xác định vị trí của key, công cụ sẽ thực hiện xóa hoàn toàn dòng/trường chứa key, hoặc thay thế giá trị của key bằng một chuỗi rỗng hoặc placeholder an toàn.

# %% [markdown]
# **Reasoning**:
# Define the functions `redact_key_in_line` and `redact_keys_in_file` to redact the identified keys based on their type and process the file content line by line, applying the redaction.

# %%
def redact_key_in_line(line, match):
    """
    Redacts a matched AWS key in a given line of text.

    Args:
        line: The line of text.
        match: A dictionary containing match information ('matched_string', 'key_type').

    Returns:
        The modified line with the key redacted.
    """
    matched_string = match['matched_string']
    key_type = match['key_type']

    if key_type == 'Access Key ID':
        placeholder = '[REDACTED_ACCESS_KEY_ID]'
    elif key_type == 'Secret Access Key':
        placeholder = '[REDACTED_SECRET_ACCESS_KEY]'
    else:
        # Should not happen with current logic, but as a fallback
        placeholder = '[REDACTED_AWS_KEY]'

    # Replace the matched string with the placeholder
    # Use replace to handle multiple occurrences in a single line if needed
    modified_line = line.replace(matched_string, placeholder)

    return modified_line

def redact_keys_in_file(file_path, potential_matches):
    """
    Reads a file, redacts the identified keys, and returns the modified lines.

    Args:
        file_path: The path to the file.
        potential_matches: A list of dictionaries with potential key matches.

    Returns:
        A list of modified lines with keys redacted.
    """
    modified_lines = []
    try:
        with open(file_path, 'r') as f:
            for line_num, line in enumerate(f, 1):
                current_line = line
                # Check if any of the potential matches are on the current line
                for match in potential_matches:
                    if match['line_number'] == line_num and match['matched_string'] in current_line:
                        current_line = redact_key_in_line(current_line, match)
                modified_lines.append(current_line)
    except FileNotFoundError:
        print(f"Error: File not found at {file_path}")
        return None
    except Exception as e:
        print(f"An error occurred while processing the file: {e}")
        return None

    return modified_lines

print("Functions redact_key_in_line and redact_keys_in_file defined.")
# Out:
# Functions redact_key_in_line and redact_keys_in_file defined.

# %% [markdown]
# ## Lưu file đã chỉnh sửa
#
# ### Subtask:
# Lưu lại nội dung file sau khi đã xóa/thay thế key.

# %% [markdown]
# **Reasoning**:
# Define the `save_modified_file` function to save the modified content back to the file.

# %%
def save_modified_file(file_path, modified_lines):
    """
    Saves the modified lines back to the specified file.

    Args:
        file_path: The path to the file to save.
        modified_lines: A list of strings representing the modified lines.
    """
    try:
        with open(file_path, 'w') as f:
            for line in modified_lines:
                f.write(line)
        print(f"Successfully saved modified file: {file_path}")
    except IOError as e:
        print(f"Error saving file {file_path}: {e}")

print("Function save_modified_file defined.")
# Out:
# Function save_modified_file defined.

# %% [markdown]
# ## Thêm cảnh báo bảo mật
#
# ### Subtask:
# Công cụ nên cung cấp cảnh báo cho người dùng về tầm quan trọng của việc xử lý khóa bí mật và khuyến nghị các biện pháp bảo mật tốt hơn (ví dụ: sử dụng AWS Secrets Manager, biến môi trường an toàn, v.v.).

# %% [markdown]
# **Reasoning**:
# Define the `print_security_warning` function to inform the user about security risks and recommend better practices.

# %%
def print_security_warning():
    """Prints a security warning about storing AWS keys in files and suggests better practices."""
    print("\n" + "="*60)
    print("SECURITY WARNING: POTENTIAL AWS KEYS FOUND IN FILE!")
    print("Storing AWS Access Keys and Secret Access Keys directly in files")
    print("is a significant security risk. If this file is compromised,")
    print("your AWS resources could be accessed by unauthorized individuals.")
    print("\nRecommendations for Secure Key Management:")
    print("- AWS Secrets Manager: Securely store, manage, and retrieve secrets.")
    print("- AWS Systems Manager Parameter Store: Store configuration data and secrets securely.")
    print("- Environment Variables: Use environment variables for credentials, but ensure")
    print("  they are managed securely and not exposed (e.g., in logs).")
    print("- IAM Roles: Assign IAM roles to your EC2 instances or other AWS services")
    print("  instead of embedding keys directly in applications or configuration files.")
    print("\nIt is highly recommended to rotate your keys immediately if they have")
    print("been exposed and adopt a more secure method for credential management.")
    print("="*60 + "\n")

print("Function print_security_warning defined.")
# Out:
# Function print_security_warning defined.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The process successfully identified common file extensions and potential formats for AWS Secret Access Keys within those files.
# *   Regular expressions were successfully defined to identify potential AWS Access Key IDs (starting with "AKIA") and AWS Secret Access Keys (40 characters of alphanumeric characters, '+', or '/').
# *   A function was created to search for these key patterns within a file, recording the line number and matched string.
# *   A function was developed to attempt decoding of potential key strings using Base64 and URL decoding.
# *   Functions were defined to redact identified keys within lines of text and to apply this redaction across a file.
# *   A function was created to save the modified file content back to the original file path.
# *   A function was defined to print a comprehensive security warning regarding the storage of AWS keys and recommending secure practices like AWS Secrets Manager, Systems Manager Parameter Store, Environment Variables, and IAM Roles.
#
# ### Insights or Next Steps
#
# *   The developed components provide a strong foundation for a tool to detect and redact AWS keys. The next step is to integrate these functions into a single script that can take a file path as input, perform the analysis and redaction, and save the modified file, while also presenting the security warning.
# *   Consider adding more robust validation to the decoding step to confirm if the decoded string truly matches the pattern of an AWS Secret Access Key, reducing false positives.

# %%
input_file_path = '/content/online-valid_1.csv'
output_file_path = '/content/online-valid_1_redacted.txt'

# Find potential AWS keys in the input file
potential_matches = find_aws_keys_in_file(input_file_path)

if potential_matches:
    print(f"Found potential AWS keys in {input_file_path}:")
    for match in potential_matches:
        print(f"  Line {match['line_number']}: {match['key_type']} - {match['matched_string']}")

    # Print security warning
    print_security_warning()

    # Redact the keys in the file content
    modified_lines = redact_keys_in_file(input_file_path, potential_matches)

    if modified_lines is not None:
        # Save the modified content to a new file
        save_modified_file(output_file_path, modified_lines)
else:
    print(f"No potential AWS keys found in {input_file_path}.")
    print(f"Content of {input_file_path} will be copied to {output_file_path} without changes.")
    try:
        with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
            outfile.writelines(infile.readlines())
        print(f"Successfully copied content to {output_file_path}.")
    except FileNotFoundError:
        print(f"Error: Input file not found at {input_file_path}")
    except Exception as e:
        print(f"An error occurred while copying the file: {e}")
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   Line 36026: Secret Access Key - DQSIkWdsW0yxEjajBLZtrQAAAAAAAAAAAAMAAHAH
#   Line 36026: Secret Access Key - hktUNEdXTk5DVVhPWlpWRzgxMElEOEVPMllZMC4u
#   Line 36027: Secret Access Key - 1vS0MWVMxrnLRpBITbfTvAgxXJIx2iYSqYB9s9NF
#   Line 36035: Secret Access Key - com/scl/fi/1efum5wgwauws8hsf22du/BTINTER
#   Line 36036: Secret Access Key - //bafkreifqwj3sxcv2abyyfhjdnjvww7p3wymw4
#   Line 36037: Secret Access Key - yCHmAOLPUETfD6VBTs1RZdb8rqUtr4VEGQmWt5KW
#   Line 36039: Secret Access Key - NdGZKCuenzhYt6QXywTDttV1LnbWkAhelHmtuCLu
#   Line 36042: Secret Access Key - QN9F4LmsolHd8v2orgUEYjIFu7dlCR3EEvOIdRjo
#   Line 36043: Secret Access Key - 1vShdSNBAPxGqOZ0X0xMxtQNGBQfcMx5mNwCxkOt
#   Line 36046: Secret Access Key - Rb5WNvpFd0OvUDwkiqBtEqf601nElp5Sk3w7T/pu
#   Line 36047: Secret Access Key - DQSIkWdsW0yxEjajBLZtrQAAAAAAAAAAAAMAAHMv
#   Line 36047: Secret Access Key - vJtUODJRNzlXRDc0RTRNTFNUQ0ZFMzI1MkNINi4u
#   Line 36048: Secret Access Key - 8637ebed634ab028JmltdHM9MTcxNTU1ODQwMCZp
#   Line 36048: Secret Access Key - Z3VpZD0xYzU1ZjFmMi04MTc1LTYxOTktMjk0ZC1l
#   Line 36048: Secret Access Key - a1aHR0cHM6Ly93d3cucXVpY2thY3JlcGFpcmFuZH
#   Line 36050: Secret Access Key - 1vRHRq118HjLOHTP3RMke8KUdUoHC9hKXg7njbRG
#   Line 36050: Secret Access Key - Lc8P9dek6hPSmhK155ExgaVKIARYCzrlCxJ98rdB
#   Line 36052: Secret Access Key - 1vRXzfMdRjbGoAjBB3SsMVLYeOsfsMbgD2iqCoKo
#   Line 36071: Secret Access Key - HLqwkFWvkciA9qdtyiGn5F3p4z5JGXCvimiJw0nu
#   Line 36072: Secret Access Key - 1vT7POGzhhbgHeFLSOb79Vwrxm9dnRH3tHBjUDaK
#   Line 36072: Secret Access Key - XiZjtr6ZjiQ0KLWZ9jMWKEjss7j0hFkgMVJco3tg
#   Line 36073: Secret Access Key - 1vSkkEheYGVghgFfoJ43ogjTi2j81uBEsaUmJDVQ
#   Line 36074: Secret Access Key - /pass/monat/fb3809ccb46aff632341676d4d9b
#   Line 36089: Secret Access Key - TqIsmfppDjAR1aWyX7IVzGAV8f4xQJFpYKW87n2Z
#   Line 36095: Secret Access Key - 1vT500XZP5L9wbD36IqdFmbOmErmsSscg6zeNUD5
#   Line 36095: Secret Access Key - AUfJ5DETPNyqX2QvEziGhezFDaReDkkgGfDLZEWi
#   Line 36097: Secret Access Key - Nx36OVqQnVGXIC0GKORjGRZFvKfpAeXaB5gbFWf5
#   Line 36100: Secret Access Key - hmHKj5DB0C9ra2HSfDaJSZ3TrIkYclssk1BBkcJw
#   Line 36101: Secret Access Key - 1vRV6QsYrmR2Zn5dVR8a4cMYKPvLZhOu55B42hMW
#   Line 36105: Secret Access Key - hrXwIRbcUEPRHlBWcYcal2nXVSjJp3c7JV5lBK1q
#   Line 36109: Secret Access Key - 1vSx0uphvucFmJr96r3hf6Luj1mxzAqf5GkoXszy
#   Line 36111: Secret Access Key - 1vRJx1OqanR2GxMLq8r6VYMo8DVt8WQM7WJ0x3ry
#   Line 36111: Secret Access Key - E9PKfRJGqhdkaUaeZLCF2LfAfWZrNF06MxsQLaXr
#   Line 36120: Secret Access Key - 1vQao0vAgWxTOZAm82SnIBpq8fkCilOOClmdT1Ep
#   Line 36150: Secret Access Key - 252FDx1yqL7nVov5pwVnAjsSImnQUrhOn56PtO5i
#   Line 36153: Secret Access Key - TOHbCMGsxrcm6Yh6xqHpplSiKSDqxGrdA5kHz76n
#   Line 36155: Secret Access Key - RLgIX80FdREB6TeNoXCLkFYHkQXp26lVtLVwlffn
#   Line 36157: Secret Access Key - FTH1HQ2OUKkaafBS9SERZDNiqVfJSC95oWqM2ov4
#   Line 36158: Secret Access Key - r9nozbrHLw6cSg6CFV4qHsAB4Kfkuv3jhn1D2DFV
#   Line 36166: Secret Access Key - TALNqTgwzOWjD1O4nvsiWk4I29txnfXAgNqbd2VB
#   Line 36172: Secret Access Key - jcLeNOLhuBJ2mEC8WOGD77WW6avlgue9g4LQPz/p
#   Line 36173: Secret Access Key - 1vShsSxfe0oPHHGJrM8Q0E9mvIaY5x5wcP8JOsCh
#   Line 36173: Secret Access Key - MNxZyMfOqByK0lZP1GOMtUqJqH3sqOQW0BlPTTc3
#   Line 36180: Secret Access Key - com/scl/fi/g972tyfxy2r7nfs2fdpqr/Securel
#   Line 36183: Secret Access Key - com/scl/fi/d86u8299ksq0j0650dxco/Btinter
#   Line 36189: Secret Access Key - lss1JqZYg0iFgZRitGseSNfmFwCK4wVFWYhbFKN6
#   Line 36192: Secret Access Key - WAV4aSPUky5RXQQn81r4E5o09Ewged3z4h9SJih/
#   Line 36193: Secret Access Key - 1yMthmeSZPz9b8BemhNLpnhfjA9G4nHbdmBijva2
#   Line 36195: Secret Access Key - 848VJGYeezgpwcDw9zMna2bIqMD2DjJDSi9PjF2z
#   Line 36198: Secret Access Key - 13005483088ec45dJmltdHM9MTcxNTEyNjQwMCZp
#   Line 36198: Secret Access Key - Z3VpZD0xYzU1ZjFmMi04MTc1LTYxOTktMjk0ZC1l
#   Line 36198: Secret Access Key - a1aHR0cHM6Ly93d3cuc3VsdGFucGFsYWNlLmNvLn
#   Line 36199: Secret Access Key - 1vSsWJbxJg9VJenhjNhBTgV8EV3bQrKVyHCgy9uO
#   Line 36202: Secret Access Key - zNOR6PoFj9c5Phte3iRqYUHxwKVwwIXt9O1deGxv
#   Line 36202: Secret Access Key - VRZZoeczqX72YfiRVxfo4aEJah8i6dw5rNQp/pub
#   Line 36203: Secret Access Key - JKgNLWHF853hJ6vYSOZkCznjmX7D5V8OBmwHRyii
#   Line 36205: Secret Access Key - iy5qiU07Wz0dcpAvEmaHmhqo9XjPwplvYUDTDDFx
#   Line 36206: Secret Access Key - 1vSNAnC2V3Pg4lkxRn2O6bmcW9KKLJtbMXG3qGQv
#   Line 36210: Secret Access Key - 1vRUcrjXlfp9s4DcnQzNTU3qQ4msYpMJ44MtWlvD
#   Line 36216: Secret Access Key - 1vT5ntWCPMuI1HkSlpPa2WVXSUtB6YT9bR5EdRBx
#   Line 36217: Secret Access Key - 1vRUcrjXlfp9s4DcnQzNTU3qQ4msYpMJ44MtWlvD
#   Line 36218: Secret Access Key - link/attyahoomaidynamicsupportservicemai
#   Line 36219: Secret Access Key - 1vTAjonXeNhwksDfaoMc91zr80evbeMKErydlcEH
#   Line 36219: Secret Access Key - qyzUPdSwBqnaLElo38m5gL0mUkFXIgTtINX62Tmn
#   Line 36236: Secret Access Key - io/ipfs/bafybeiaf3dwtoccnrlsuca7vmus7mto
#   Line 36236: Secret Access Key - xwk26lsj46ef46f7oujea5qsexm/IS3QmSqtDrDi
#   Line 36236: Secret Access Key - n1wKa43QmS1wKa4SqtDrDGyjs5KEYqznxpHMFr9h
#   Line 36236: Secret Access Key - VPSX5pyQu1u3QmS1wKa4SqtDrDGyjs5KEYqznxpH
#   Line 36241: Secret Access Key - czL7lpEUrO8RY7qgHYo8pwYZK8dZZZdMTRjEiAj2
#   Line 36242: Secret Access Key - czL7lpEUrO8RY7qgHYo8pwYZK8dZZZdMTRjEiAj2
#   Line 36248: Secret Access Key - content/particuliers/aces/particulier/lo
#   Line 36249: Secret Access Key - content/particuliers/aces/particulier/lo
#   Line 36253: Secret Access Key - cozsidAAQkA000000003344556edfdfgthy00000
#   Line 36253: Secret Access Key - 000000000DZgfdgdYyLWY5gfdgdYyLWYghgyg999
#   Line 36254: Secret Access Key - dev/tQGNvbnRpbmV5596132FnwQAQF8bIbie7MIW
#   Line 36254: Secret Access Key - 252FbWFyaWFtQGNvbnRpbmVudHRvdXJzL34bc434
#   Line 36254: Secret Access Key - 841be302db40040cc60C5xDaM6VOVr6n4RfiKPaJ
#   Line 36254: Secret Access Key - EkuHdPJxvVDf3t660LAAvqub1qcUheieNOgERVX7
#   Line 36257: Secret Access Key - 1vTV8gHOuyrVbT1pU1P5ChMIG2goXCOK1vbUwBNY
#   Line 36258: Secret Access Key - BJ8WEus0SNgoZVWfEms0dMtzQUVmISNReahkhWnj
#   Line 36259: Secret Access Key - fmWwLH2rinnQgF6bmivysdMvrBNv8QJqnLGPoXlF
#   Line 36262: Secret Access Key - Yrj3rLOiu0ja5PqLKftRA6GWKdJVavbrffjANeGg
#   Line 36263: Secret Access Key - HzJAm0fyd0Rj471MAZrK0VZkMtj8qs4cOf499fY7
#   Line 36264: Secret Access Key - RVQQuzJeqdoQVg633HLvjJdoyhWZ0pbvySeJbrga
#   Line 36268: Secret Access Key - AOmngpt6J473F8t5P37WLNio9Hq323eKu2u7Fmll
#   Line 36270: Secret Access Key - 1vS3NX87DCRqQ6csxV8yHKhj5uLjLssDx2ZBlosT
#   Line 36273: Secret Access Key - d00fdce50503c4f3JmltdHM9MTcxNDk1MzYwMCZp
#   Line 36273: Secret Access Key - Z3VpZD0xYzU1ZjFmMi04MTc1LTYxOTktMjk0ZC1l
#   Line 36273: Secret Access Key - a1aHR0cHM6Ly9jbGljcy5pbmZvL2VudGVydGFpbm
#   Line 36273: Secret Access Key - 1lbnQvLW15LWxpdHRsZS1jYXJhdmFuLWNyYWZ0LW
#   Line 36273: Secret Access Key - JpcnRoZGF5LXBhcnRpZXMtZm9yLWNoaWxkcmVuLW
#   Line 36274: Secret Access Key - 58882b7604e17298JmltdHM9MTcxNDk1MzYwMCZp
#   Line 36274: Secret Access Key - Z3VpZD0xYzU1ZjFmMi04MTc1LTYxOTktMjk0ZC1l
#   Line 36274: Secret Access Key - a1aHR0cHM6Ly9jbGljcy5pbmZvL2VudGVydGFpbm
#   Line 36274: Secret Access Key - 1lbnQvLW15LWxpdHRsZS1jYXJhdmFuLWNyYWZ0LX
#   Line 36280: Secret Access Key - K6KSnZbYdX9Hp9hWkOvx4AOn6xJ5O3acXR5CFog9
#   Line 36283: Secret Access Key - dev/EgZjaHJvbWUyBggAEEUYOTIHCAEQABiPAjIG
#   Line 36294: Secret Access Key - r3vvTF+xzt/ILAnk1T1P1bTbPx0q4qJ4XuSkkrpe
#   Line 36294: Secret Access Key - 7/6TvzmTzv/sj/GUxJPM+qju+JczOxa1S1AqT6vC
#   Line 36294: Secret Access Key - 0Y3OW3DTTNBZmlvkUEBJKCUBeUyHVt1DEMuCUr8W
#   Line 36294: Secret Access Key - XDC7itLX2XmJkDgMSsND9x6Z/J7q81AZTBcNCTfQ
#   Line 36297: Secret Access Key - prefixed/swiftmailer/swiftmailer/lib/cla
#   Line 36297: Secret Access Key - bD1odHRwczovL2xvbm9zbmV0d29ya3MuY29tL3Nl
#   Line 36297: Secret Access Key - Y3VyZT8lN0JyYW5kOkslN0NIJTdDTSU3Q0glN0Mz
#   Line 36297: Secret Access Key - JTdDNCU3QzklN0NFJTdDOCU3Q1IlN0NIJTdDOSU3
#   Line 36297: Secret Access Key - QzMlN0NNJTdDViU3QzYlN0NuJTdDbSU3Q24lN0Ni
#   Line 36297: Secret Access Key - JTdDdiU3Q2MlN0N4JTdDcSU3QzUlN0M5JTdDMCU3
#   Line 36297: Secret Access Key - QzYlN0NoJTdDOSU3Q2wlN0M1JTdDZyU3QzMlN0N3
#   Line 36306: Secret Access Key - com/scl/fi/fc80ylgwj72t3a0y9poer/BTINTER
#   Line 36311: Secret Access Key - 1vQYP8zr1yxsfHd9KIRpNwhWt03hakmnk2FOYwca
#   Line 36313: Secret Access Key - 1vR35b7rhkzv8OeL4D2HZwAZiGCG7FmzFwUuQyP1
#   Line 36313: Secret Access Key - M1ipl5PTnQvxXBtVEuWqcXLLK70VpEGSz1ENqAMo
#   Line 36316: Secret Access Key - 1vQD5uGqVLrGNJM4OoZDiNRcDfBE0HGdCQHI0mfD
#   Line 36320: Secret Access Key - 1vTFQW5Yytf7C34LShfTEnKYkuAkqxkujigOZqr2
#   Line 36320: Secret Access Key - 7990UXVlXrfSQ3yi4AoSGDCVw3S9nkS4Gb7M6Jf4
#   Line 36321: Secret Access Key - wUSiYmvZ6gY9hUVIIVCrq1EeQEzggrpIqfLSqTkr
#   Line 36322: Secret Access Key - uckYvXxiDS3S5YpdzI5vkWnv2qhK0LQVultrinNV
#   Line 36323: Secret Access Key - ofKKv49b3S40me1vroj4JPF36iLFlO7bz9N37jMa
#   Line 36331: Secret Access Key - jP9cLN0gcN1HPThVkLvsH7amjDByIqtmekNC7HrO
#   Line 36343: Secret Access Key - LruAk9EiT4BMD23o0v3lgU91riYrv46ScPEeQsHt
#   Line 36348: Secret Access Key - dev/USER19042024UNIQUE094004193920242024
#   Line 36349: Secret Access Key - dev/0042024UNIQUE08230430432024202404302
#   Line 36349: Secret Access Key - 253DO4ECJ6p0xWACZ682uuprWTDWQLedDqjE4Myn
#   Line 36350: Secret Access Key - dev/0042024UNIQUE08230430432024202404302
#   Line 36350: Secret Access Key - 253DO4ECJ6p0xWACZ682uuprWTDWQLedDqjE4Myn
#   Line 36351: Secret Access Key - 1vR8Flm9VNcqghgEgEY78zpQpqzvfT8QwUrruQpo
#   Line 36353: Secret Access Key - H5y8YuCf5PEkFNqNQjCSVktInWXfcAqB6nUQ4YoK
#   Line 36354: Secret Access Key - 1vSpzabxAjg6m25ylZa1It6kpQROrbyBO20WWFlr
#   Line 36354: Secret Access Key - l4BAARTyOCmh4TCbfDQNQGpf1dPCJtSfk29bJ/pu
#   Line 36355: Secret Access Key - //bafybeiaqmaet5wahny3zixwa74zg3c5wywxpt
#   Line 36360: Secret Access Key - com/scl/fi/nuztnr258levcar3lr48e/Securel
#   Line 36363: Secret Access Key - kUMs6JvUUXew1lvfUesVztvzoISAQqD9EiHIQX9T
#   Line 36364: Secret Access Key - f0cfdf16a156b8f0JmltdHM9MTcxNDYwODAwMCZp
#   Line 36364: Secret Access Key - Z3VpZD0xYzU1ZjFmMi04MTc1LTYxOTktMjk0ZC1l
#   Line 36364: Secret Access Key - a1aHR0cHM6Ly9jbGljcy5pbmZvL2VudGVydGFpbm
#   Line 36364: Secret Access Key - 1lbnQvLW15LWxpdHRsZS1jYXJhdmFuLXNjaG9vbC
#   Line 36385: Secret Access Key - dev/SWXEFFCFCHCJHBVJKTEU8IYHTU7SGHFFFDGV
#   Line 36398: Secret Access Key - dev/5REDFDFTRFDGFYFSCXGVCHVUTTUY7FGHBFER
#   Line 36398: Secret Access Key - 34EGFCGBCFGBHVHNBHTYTHFGVEDF3ESDFDGVCBFV
#   Line 36400: Secret Access Key - 2FUSER29042024UNIQUE10340429112024202404
#   Line 36401: Secret Access Key - dev/73NSDYUF8Y8HXCNE7RTXDUGCVUBRT87ET87D
#   Line 36401: Secret Access Key - XTFYVXCUFVG8FYXUIHBVCFE7T7UGFCV7TR7ETFET
#   Line 36404: Secret Access Key - dev/USER30042024UNIQUE082304304320242024
#   Line 36404: Secret Access Key - 253DO4ECJ6p0xWACZ682uuprWTDWQLedDqjE4Myn
#   Line 36419: Secret Access Key - 1vQd6jwkxrccxaR3TrwBmZq9nHxrLzWMSnhzQUev
#   Line 36420: Secret Access Key - 1vRxpsQEGTcPU1djo7ZW9k6O6ZVfraTVYhhyqBYH
#   Line 36430: Secret Access Key - //bafybeifgzx4io3dzbvis5ts2t24kltun72lzv
#   Line 36431: Secret Access Key - //bafybeifgzx4io3dzbvis5ts2t24kltun72lzv
#   Line 36432: Secret Access Key - ZlJdBhBUCyprYGTTNfU9Pu4uryFoMzdmzTnSExuM
#   Line 36436: Secret Access Key - 1vSTqz5nWfyxMry586hHWV9CGjFcHUzZ9iiFYH6V
#   Line 36439: Secret Access Key - RPcpPvXLP1HEqyOyVptlD7MZwJ8hkJJgpKkB1aT7
#   Line 36440: Secret Access Key - 1vRc4uqiyd5siqx4tyxTBTFxVqJQR1K113PoHKx6
#   Line 36442: Secret Access Key - 1vQdZD6A6pdUzIkoR0GhDCOJ2lhhI8x07n9lO4KN
#   Line 36448: Secret Access Key - 4NXfu8RAcqxLYQF5AKWhW4CRcvtMfI1cSQzI7Y00
#   Line 36451: Secret Access Key - E3g7VVkvooEBzgv5kO6aBaTmTqwQcyE5FmZPYf1i
#   Line 36452: Secret Access Key - com/forms/d/e/1FAIpQLSefHBrrDQFwnxBDr6Jw
#   Line 36454: Secret Access Key - 1vSElBhH1togrbP3l0RfvU2pFoEVXLt9G2hCfRw6
#   Line 36457: Secret Access Key - 1vRc4uqiyd5siqx4tyxTBTFxVqJQR1K113PoHKx6
#   Line 36463: Secret Access Key - pBjL5rkAR7hAXuMgFFTZw2mhOcflarYnLkYqHi4L
#   Line 36472: Secret Access Key - dev/8FDNKJNGVJKGH8IHCJHBVJKTEU8IYHTU7SGF
#   Line 36472: Secret Access Key - DUYXZGCJXBVJKVBU8T4HGIUDHGBVJXCBVJCBVJKC
#   Line 36478: Secret Access Key - 1vRAagK5vmH3UDK4Yy6JgL9O2a4cfWZt4E0WmLh2
#   Line 36478: Secret Access Key - BFs25BQPjgdC54Op59aETgBHG2qrIwYU80gwGmcf
#   Line 36480: Secret Access Key - telegrampoiuytrretyuiopkiouytrefghjkytdc
#   Line 36481: Secret Access Key - 1vSUkzw4Tx9ppiQ3ls0z3DYydD4jQ2nyWIxPU0gl
#   Line 36482: Secret Access Key - HowMq9CGNVkFKX8onqheSiVxHUryNygIoIQIK28k
#   Line 36488: Secret Access Key - eyJ0ZW1wbGF0ZSI6ImNjX2NvbGxhYl9kY3NoYXJp
#   Line 36488: Secret Access Key - bmdfdmlld19lbWFpbCIsImVtYWlsQWRkcmVzcyI6
#   Line 36488: Secret Access Key - InBoZWFkcmEuZGVyb29zZUBnbWFpbC5jb20iLCJy
#   Line 36488: Secret Access Key - ZXF1ZXN0SWQiOiI2MDM4ZmI0OC0yYzY2LTQ5OGIt
#   Line 36488: Secret Access Key - NDM1MC1hZTlhZTQ1MWFmMjciLCJsaW5rIjoiaHR0
#   Line 36488: Secret Access Key - cHM6Ly9hY3JvYmF0LmFkb2JlLmNvbS9pZC91cm46
#   Line 36488: Secret Access Key - YWFpZDpzYzpWQTZDMjplMjIyMTI2NC0wZjdhLTRl
#   Line 36488: Secret Access Key - OTktOWQxZC0wZGU5YzQwMzRkYjQiLCJsYWJlbCI6
#   Line 36488: Secret Access Key - d6bVtI8KywRLxclpWNg1pDUCJKo3TF01PmJua7ug
#   Line 36492: Secret Access Key - 1XmBdfOVa9fTcXmVAF7S8H81H3LrjauYuDFS6o3L
#   Line 36493: Secret Access Key - 1VpSVypq7Eo3hloeGLeRBhrM05n3NZ1hhu7SW2Pz
#   Line 36494: Secret Access Key - 1vTWlWMb5WAeT614KPs5PrUMwfoRieu4llBMwOyb
#   Line 36496: Secret Access Key - 1vSf9U7IDpboN8aKLdVewdqXlrDagvqjKQw28vXL
#   Line 36496: Secret Access Key - 70EZXuFS5ez8vKE27fMXA9SclHxGx63C4YmY7Hq1
#   Line 36497: Secret Access Key - 1vSUkzw4Tx9ppiQ3ls0z3DYydD4jQ2nyWIxPU0gl
#   Line 36498: Secret Access Key - 1vSUkzw4Tx9ppiQ3ls0z3DYydD4jQ2nyWIxPU0gl
#   Line 36512: Secret Access Key - io/ofcaserestricnow/aces/suspendsioon/te
#   Line 36517: Secret Access Key - wNSH8HNpIjbYFx0BunKAmapzkS18IjJJsk5vyrWX
#   Line 36550: Secret Access Key - 7eDrriMHM0T4atGLkqS4Kc3Nv2HAFHvxi9TWd2jL
#   Line 36552: Secret Access Key - 85c6242dd6652f34JmltdHM9MTcxMzU3MTIwMCZp
#   Line 36552: Secret Access Key - Z3VpZD0zZWU2NDQ1Ni05NjlhLTYzYWUtMDc4Yi01
#   Line 36552: Secret Access Key - a1aHR0cHM6Ly93d3cuemJhcHBzLmluL2hvbWUuaH
#   Line 36552: Secret Access Key - 06f204159369215d425560ff5e90240889df07dc
#   Line 36553: Secret Access Key - 1vQWlHFdhXoF9qEktWydoAotGpcOAarGmCyBi9Uu
#   Line 36556: Secret Access Key - 1vR0sXZBL23b350MvXWsaJKV7ZS7HZNe1XnjvjLV
#   Line 36557: Secret Access Key - YgpikDpBRKC9DnH2F4iVRLUlheYaDe7c5sCZ9mN1
#   Line 36561: Secret Access Key - //bowkwpoedjjeodkkseksdnkdnfndnebebbdbdb
#   Line 36564: Secret Access Key - 1vRy13Dlzs34HUzAb8dbJpgGPRlOn6nyRLzSEEYV
#   Line 36565: Secret Access Key - YLzRCAsJFTVuD3CjQn0KQLrVCFabMyc67SHgiuUt
#   Line 36575: Secret Access Key - io/v1/2/Hb0d2Uj0r95jpRtxOwI7AtYqm8q6BxFG
#   Line 36575: Secret Access Key - Dz5p8QIOuyjypgrUkCFi6FXJPBAxHt4EMSjpIF3g
#   Line 36575: Secret Access Key - /pwtAbdY3WBsALp1JzM2D6F0NdDIvR73V6CxxxyY
#   Line 36575: Secret Access Key - pwtAbdY3WBsALp1JzM2D6F0NdDIvR73V6CxxxyY5
#   Line 36578: Secret Access Key - 1vQvkp76vcwKbONNSgeDpVDaDZQ17QxjdjWzxACt
#   Line 36579: Secret Access Key - 1vRzaqSWdifshSa2wIwBwNvYFTE0jXtTjPuJfCG2
#   Line 36581: Secret Access Key - 17fOi58xXlEKweb52bGLe8ObK43v9VKMr7LNeV3Q
#   Line 36584: Secret Access Key - XNsP8NY8nOhbhdyZ0BOU6g40Z3Rc8MF7IBBVGjwS
#   Line 36588: Secret Access Key - 1vRzu0qbkfTyx715xdEmNmDYuzzySvCKCcAcL38h
#   Line 36589: Secret Access Key - 1vT4E1G1zh5NFu85a3OBd9B9g0drZXPNCRRD7ZB4
#   Line 36591: Secret Access Key - 6O78N4ebCtArj0IFeyCloxYM0soR8mCZg3wOkl9v
#   Line 36592: Secret Access Key - 1vQSTRuSjrImE6CxPVmmYjYmHs7kZHuW3pcEmNRm
#   Line 36593: Secret Access Key - ey7I3OtgVYZ9CqSbWWh6ufuRyTUm5oCpmCydFuTd
#   Line 36596: Secret Access Key - 1vRP4DMSuVdvuSQpCJulwIqRdqNzpTC1adGguVYO
#   Line 36596: Secret Access Key - q7mcSyAq0E1K49lL60Jxsm7mo7BBIiivPFeAjMYF
#   Line 36597: Secret Access Key - com/view/oiuiruieor98490krejjkljklejkef/
#   Line 36598: Secret Access Key - com/scl/fi/oy34u7nxilsnnw1adtg1u/Securel
#   Line 36604: Secret Access Key - 1vS9sJOqDQGiy7I7A2bypfl7e9bWEE8hL47MqGsA
#   Line 36604: Secret Access Key - 8XBsq6GAIyIOYcFUa1E2s0XZt0ZPYA9rDRumrsRY
#   Line 36605: Secret Access Key - 1vQ4JqNki4NYPJowqvSnDa0dUaoYHsAeJBMw02Vt
#   Line 36609: Secret Access Key - jfTPA1USehYXasK3XPqhv9Ach1cLaxFyoCcV3l0V
#   Line 36610: Secret Access Key - 1vR4oOPdSV8vBlZNV1GRacY3fasgivSFelF8vwKK
#   Line 36610: Secret Access Key - AFUtX4osaar5Ljyc7fIN4R9DqovLKKTWZAVrUGT8
#   Line 36612: Secret Access Key - 1vQBfHEnUIKSTQDH6Dhh9AK3UdLi1FKrIZoqlVuV
#   Line 36615: Secret Access Key - 1vRgVRgYVajNfJlK3YaRvTwuo8mgdGV9xmhy5Jk8
#   Line 36616: Secret Access Key - 61rlcsYNEqSVuSTZRtdXJ8tQrdCr1iNtCOJmLdut
#   Line 36625: Secret Access Key - dev/traffictacticsdexcnancncayhssncnanxn
#   Line 36638: Secret Access Key - 1vQI2gtM2zgQVOVWUy3P0jekinIKvjEHwluihIeV
#   Line 36644: Secret Access Key - zNsLuOHuLfs8nQQ1d6PtTLwCG9bxi3Zlg3SQU2SW
#   Line 36645: Secret Access Key - q7b74tlkDpHqmcgtrCYTns0xWjmAqjCiL6zF1Xaw
#   Line 36647: Secret Access Key - TS3syKM2gkIxEVbzYCirDf7i4QZ7b07d1mjkiS66
#   Line 36648: Secret Access Key - zd9RsaPDHKHSI7A7j4BHKkzpNbhnJkclpDfh0mM5
#   Line 36649: Secret Access Key - 1vTn1cAfJcqoOgJBAC6gwtA2YDFvhUplMK3XqGTW
#   Line 36652: Secret Access Key - com/scl/fi/qyesaiwglti9vpk5ozh8f/Securel
#   Line 36653: Secret Access Key - com/scl/fi/10fsrsuo02jdu4b596zcf/Securel
#   Line 36655: Secret Access Key - com/scl/fi/5s1az4lo89c319l7v7l96/Securel
#   Line 36656: Secret Access Key - com/scl/fi/eolrec1wqdm1y2n9d0o3s/Securel
#   Line 36657: Secret Access Key - com/visit/KZgyyEn/kb1ao7pBgmXRxaDG/alleg
#   Line 36659: Secret Access Key - 1vShK3kH1dbWjVdyWvtIkOFVpSOEqAQDrbeDt5nO
#   Line 36659: Secret Access Key - v2SNqyBdHhwcKxMvu7MWjaPbhl5l3GHHhZPPoWFj
#   Line 36660: Secret Access Key - 1vShK3kH1dbWjVdyWvtIkOFVpSOEqAQDrbeDt5nO
#   Line 36660: Secret Access Key - v2SNqyBdHhwcKxMvu7MWjaPbhl5l3GHHhZPPoWFj
#   Line 36663: Secret Access Key - Q6AxYkGMRRVK3uaCYFV0v3hZ7wV4zMIonCaj05ZN
#   Line 36668: Secret Access Key - 1vRkSOm0E9yl9Nu86vpsFMUAaAWWSW8aYImZuSEC
#   Line 36676: Secret Access Key - com/scl/fi/s76ix3f5cadu4gtszjqbs/Securel
#   Line 36682: Secret Access Key - lkofdujhfuhyhuhdbnjfgvreuithuerhudhgbbui
#   Line 36682: Secret Access Key - jknvkjndgiurhuhgtdjunbvjdnburihguhbujcfd
#   Line 36686: Secret Access Key - com/scl/fi/p6ql4363wqkoumdmh8lt0/BTINTER
#   Line 36690: Secret Access Key - com/scl/fi/1e87r7w9m55qchju2dz98/Securel
#   Line 36691: Secret Access Key - com/scl/fi/mdih7dloobwzdhsl57dag/Securel
#   Line 36694: Secret Access Key - IDBngIHaCXHbBmuAoddDxAyOSjDhAsxD0LE3NrKF
#   Line 36695: Secret Access Key - 1vR2a5HVDrlKzfEONdeiKG9u6U7RwzX5WRqxkkcW
#   Line 36696: Secret Access Key - com/scl/fi/4wgsvy5ae4ye9cpbkehkf/Securel
#   Line 36697: Secret Access Key - 4KXBbAUxfjcQd8v9zG0gS2wJpxMR5cM7BrRiwh8r
#   Line 36698: Secret Access Key - FaqkHy5GKQ74j9vjp1apuU9h2H4J4ZKlOixnfDDA
#   Line 36705: Secret Access Key - 1vS6S4TS4QPyDZEIQPlcy8JHpBW5gweXbGJvkxQi
#   Line 36705: Secret Access Key - pj4kYISNLw7WakRBUr6wcMEhoXqRN0wNIQOpwIal
#   Line 36708: Secret Access Key - 1vSTDB6xyqKNLeqDfxp6HCkImzYdbYJm56v48Lzs
#   Line 36715: Secret Access Key - ZSuXpSvue0UfKrOXnU6mQAuN0RcLmvWGTqSCzhKl
#   Line 36716: Secret Access Key - AaSxoQyQEeCdGiNQploah5nAij7vrMqrlVIHby1Q
#   Line 36717: Secret Access Key - AaSxoQx8KpKqyfYOhpBhxXOwlr4BDkOhHexmZQI7
#   Line 36719: Secret Access Key - //franklinpierceschooldistrictemailverif
#   Line 36725: Secret Access Key - 1vRKmx5gEKJBBWB6FZdMWZNxrftZBuLqdL5lywpn
#   Line 36725: Secret Access Key - jlIKG9Uh0MTgxYhclN3lr6PyGynksEGTpGBZA4fJ
#   Line 36728: Secret Access Key - com/scl/fi/8pmjdjp0246tkvlmedl00/Securel
#   Line 36729: Secret Access Key - com/scl/fi/0bmxur6f5aaxmr7k9cwmb/Securel
#   Line 36734: Secret Access Key - eyJ0ZW1wbGF0ZSI6ImNjX2NvbGxhYl9kY3NoYXJp
#   Line 36734: Secret Access Key - bmdfdmlld19lbWFpbCIsImVtYWlsQWRkcmVzcyI6
#   Line 36734: Secret Access Key - InNlZ3JldGFyaW9hdmlzY29sb2dub0BnbWFpbC5j
#   Line 36734: Secret Access Key - b20iLCJyZXF1ZXN0SWQiOiI3ZDg1YjZkMi0zNjg1
#   Line 36734: Secret Access Key - LTQ2ZTgtNWNlYy02MjgzY2MzMGQ5OTUiLCJsaW5r
#   Line 36734: Secret Access Key - IjoiaHR0cHM6Ly9hY3JvYmF0LmFkb2JlLmNvbS9p
#   Line 36734: Secret Access Key - ZC91cm46YWFpZDpzYzpWQTZDMjo0MGM2ZGU4YS03
#   Line 36734: Secret Access Key - NTc5LTQ0MDctOWEzOS0wNDU4MGVmMTUzYTciLCJs
#   Line 36735: Secret Access Key - com/scl/fi/nhxrb6jo73q7yzcp4r23k/Securel
#   Line 36757: Secret Access Key - 1vSVjWXCmFE9tWaoZbSJX4aUjjUM6Qx7NvJXL2kJ
#   Line 36759: Secret Access Key - rkcPQPMe3das3e4Llm6v0s7rNP4hvDD2jcakov7P
#   Line 36761: Secret Access Key - 1vQMGQ0HVCH476hEy7s101SGnFgCwkdYcaU1ZQzI
#   Line 36773: Secret Access Key - 253DO4ECJ6p0xWACZ682uuprWTDWQLedDqjE4Myn
#   Line 36778: Secret Access Key - dev/fccx8uyihfsjkibf398ry8s73r45sdyfhjsc
#   Line 36778: Secret Access Key - vbkr30ru9rsojhcnlkxcnbi3trg8wfcyfvzxjcvb
#   Line 36781: Secret Access Key - rIxYTFXhMMnZWG4wmojTba95Eo2wXMK98IxmQe9f
#   Line 36782: Secret Access Key - 1vRTnBTsDKUDqdS7FWXwMxf4Rkqu2SXou2V4VO3W
#   Line 36782: Secret Access Key - imd1P4jeUhG2ms1KaLlU19jxM4xdiN1AkduYp6Yc
#   Line 36784: Secret Access Key - com/scl/fi/2v4dexvi35a106xd5bj1k/Securel
#   Line 36786: Secret Access Key - 1vRkEXXgNmgQNg1yY5BiF62KuDm2Mhc44KGZUrYL
#   Line 36787: Secret Access Key - AKAOjssyyO0wZS6nrn4QFiqdYKqNllk6QFSyOwvF
#   Line 36787: Secret Access Key - LS7EUdUoq0AS5z00r8YW1RwSvZtNXgt6dRog8wWi
#   Line 36787: Secret Access Key - r2rHYmzaIbaQTx1vz8nAqhQ82g3Azcl25Quelqpi
#   Line 36787: Secret Access Key - V1KLZGRavxCEGvkGDoqnjV3jU78r2TlN4T1kN5oA
#   Line 36787: Secret Access Key - aaI5XDkiyNoEtwl4uxLVfPlGpCrgNrDIlgh9f4LK
#   Line 36787: Secret Access Key - gBAB6IE9kowlBFBEImFi9JFDisghQFo0HyRcQgiY
#   Line 36787: Secret Access Key - bc5BNVWnuscEml3iT6o9EHxul20ij9J3HoORbFQP
#   Line 36787: Secret Access Key - MoGi5aFNeFIrOfvETF5AWuvm0hguQzJH8O7XmtWT
#   Line 36788: Secret Access Key - 1vQCjqgvdWdFmXMHu9vqf5OygBxn9ihnyiJXkxN5
#   Line 36788: Secret Access Key - OJFXtiLSuW6jOVp41O8iX2NucfMcz3IeSRD1aBuo
#   Line 36790: Secret Access Key - 1vTb5DgYa7pr0rP1OvO10qcVlFAZmFIgKOjweWVd
#   Line 36810: Secret Access Key - //attgktifrivjfdkdf49fej3ituvjv393ui93kc
#   Line 36811: Secret Access Key - 1vTgca879kQqoZ06YmLGhZShzVFqXolPd6ir6xWn
#   Line 36816: Secret Access Key - 85c6242dd6652f34JmltdHM9MTcxMzU3MTIwMCZp
#   Line 36816: Secret Access Key - Z3VpZD0zZWU2NDQ1Ni05NjlhLTYzYWUtMDc4Yi01
#   Line 36816: Secret Access Key - a1aHR0cHM6Ly93d3cuemJhcHBzLmluL2hvbWUuaH
#   Line 36816: Secret Access Key - 646be767c0acd7d7036815523ca75fc2171354f9
#   Line 36821: Secret Access Key - 1vTUvOmbOSjYvhaC5uIfcy2OottjIz55JKViJMk5
#   Line 36828: Secret Access Key - 2dxrXUEIF4to3FuuYXr2ixCQbfQUgwd6ysvabhpY
#   Line 36831: Secret Access Key - 8Y36737gc2TdlW6WT4FwidcTtMvztKrNCfhj5Wvl
#   Line 36833: Secret Access Key - 5qUONIdxPeh1GYB2O1dPIUt1xLqwKFKKcNFpSBCB
#   Line 36834: Secret Access Key - 85c6242dd6652f34JmltdHM9MTcxMzU3MTIwMCZp
#   Line 36834: Secret Access Key - Z3VpZD0zZWU2NDQ1Ni05NjlhLTYzYWUtMDc4Yi01
#   Line 36834: Secret Access Key - a1aHR0cHM6Ly93d3cuemJhcHBzLmluL2hvbWUuaH
#   Line 36834: Secret Access Key - 4a370d660959e88331534b3e522a1081e4483511
#   Line 36835: Secret Access Key - 85c6242dd6652f34JmltdHM9MTcxMzU3MTIwMCZp
#   Line 36835: Secret Access Key - Z3VpZD0zZWU2NDQ1Ni05NjlhLTYzYWUtMDc4Yi01
#   Line 36835: Secret Access Key - a1aHR0cHM6Ly93d3cuemJhcHBzLmluL2hvbWUuaH
#   Line 36835: Secret Access Key - 48b6c161d850a9726739082b882612d82dcc2e04
#   Line 36839: Secret Access Key - N5thG9T4vuETpMutWhJHTCu6jH0yYDBKBk4vLwOD
#   Line 36846: Secret Access Key - XLT05gV9ZItJTW7LJ20gEdeHDt6jQIhrDnaLQkX1
#   Line 36848: Secret Access Key - 1vS2yIMZAYEtxNufbVEZF95zvz1k55GDGENrEPVo
#   Line 36852: Secret Access Key - //bafybeiaamq7qrezzm7cbko4e6hl5c3fcjqntu
#   Line 36853: Secret Access Key - 9iQIdng6s61wOv8fwZ1Dsgubi03jeLMO00WMyRjQ
#   Line 36868: Secret Access Key - te9nIPtmzKfTDfpiXWId5zmn2QUEDxnYV6aoKTJA
#   Line 36872: Secret Access Key - 1vRgnmbUtvSVJib7pecjgCMLG85xOezZVSpgilgB
#   Line 36875: Secret Access Key - lX23zUHgJWgrwRe8wQM5kid87eRt3HhCJ1NvzI3b
#   Line 36876: Secret Access Key - PhHwsopGoe3Jyv06PPRfgiGmNv89nucLuqnZ39Zd
#   Line 36884: Secret Access Key - xQWavaU2aTnMUCl10lCEFKuRSjBtVDkl0U7wGEDK
#   Line 36889: Secret Access Key - 1vQiu6KxqqAqwan080wXJCfDzcxmxr5MC1prygxe
#   Line 36889: Secret Access Key - YNHet7QA68ZFox7aKSXerjnKMH3qFygwg1nIALmJ
#   Line 36890: Secret Access Key - 1vQsP2VZTYu1tYHVh607tLh3BmFRIfj0uyxgDkA4
#   Line 36893: Secret Access Key - QWtEH8F6bUnwec34aHyWmZi9kpFUj051b7NluVyz
#   Line 36894: Secret Access Key - Be9QT4UjYMrCb8iCXCeG7MY6jFqdCz6gGpjpBZtv
#   Line 36897: Secret Access Key - 1vTJ6zrjC0MNP69VFjy7ogN803JSTbiZXRM4PfMb
#   Line 36897: Secret Access Key - GDznFbqYW5WAFYyNxA3DmcAEV0PuujK8RBqybkoR
#   Line 36906: Secret Access Key - dev/d9jk37656sgvb9925244svsb89864vsbsj99
#   Line 36906: Secret Access Key - snbbst5526799ssn983835rssdh9340ndnd72365
#   Line 36909: Secret Access Key - lkjhgfdertyuijkhgfdwertyhnexecvbnmiuyrew
#   Line 36910: Secret Access Key - RcH7RZquXOHqlT35Na387eqy5bReToaYA3H/pubh
#   Line 36911: Secret Access Key - 1vT08pX4piTbpLDJS00Jq5tzkiKrVmEjIL14Zqh7
#   Line 36913: Secret Access Key - Og0K8eNrDrY7TCtQsxsIjZXsD05mXSSFEmnKmfnr
#   Line 36914: Secret Access Key - QLRiFqxupiXzPyEjAxU7um2Ja9uNtGq3u2vioigr
#   Line 36916: Secret Access Key - 1vRmNHchTEjKU0rFJ964YjWUsFE2xHjFNCmPGsO7
#   Line 36918: Secret Access Key - com/QEexBoC0tCwrSJRy9SqVxxvQyJVih76czsHp
#   Line 36919: Secret Access Key - //bafybeianhemaxm75q2m7mp3stg4jthr45qv5j
#   Line 36921: Secret Access Key - 1vRdxTD6EmZAXlbPAWnWACcVoKVLt0iLFNhX25sL
#   Line 36921: Secret Access Key - hD0OA9RxqwRlyPYZI66CbvYc1YHm4yukn3Yt377T
#   Line 36922: Secret Access Key - a6jrREKLfvCRWyFXZSc0SFVi13O9lr11oszhRm0C
#   Line 36936: Secret Access Key - GscL6PEVdxl55OmBOpReCRrlrQVKqBR0jTvOexSN
#   Line 36938: Secret Access Key - 1vSOWK2gApXJTlExajk3RUCPxt98XiouX4Zx1Hbj
#   Line 36940: Secret Access Key - GNsBu71vvQRbOyVwe8g6nlzQ1eWUMBg34Rh0TZYA
#   Line 36941: Secret Access Key - 7FtdQI9HeJZHbgQz9CFWJ8yJazqNHTqTVMML/pub
#   Line 36943: Secret Access Key - 1vQ1J8HXQx71OcJztETFQJjdpgb3N3rXu1evvlmo
#   Line 36946: Secret Access Key - jY3mfdbIpCKHOQmRF7U6XGinZ9J8qeYZnokAc/pu
#   Line 36948: Secret Access Key - gykcMmaFyQNHOQnX90YO9V1jjDcX9RuEjabIi9XU
#   Line 36950: Secret Access Key - 40UVfCd5cJRsLhg8ViSKz6W3PxYHp3CYEpbuYWG9
#   Line 36951: Secret Access Key - S8SwrTb3TxQOnYyTJ1JcXzrpdhf3U9W71YuFKlth
#   Line 36964: Secret Access Key - gijU21p72bZh3tr2C55ybbU9BJOGfnlLcPT5GhI8
#   Line 36965: Secret Access Key - uRAKxX6cmZPMLFmdzB5LuTN473n2Acuhb2haSUH/
#   Line 36968: Secret Access Key - 64uXXo7diIm2qw6rS8iyhi15ENng3LTMAOpVHXlL
#   Line 36978: Secret Access Key - dwajXRV4ntV9I7PlKNq8ylKkZvoyVPoQ3pCbrIUj
#   Line 36981: Secret Access Key - 40UVfCd5cJRsLhg8ViSKz6W3PxYHp3CYEpbuYWG9
#   Line 36982: Secret Access Key - Bs3NcEadz7tOXZmI07XU7e4xYuRgLEVEbybznpmn
#   Line 36983: Secret Access Key - Bs3NcEadz7tOXZmI07XU7e4xYuRgLEVEbybznpmn
#   Line 36984: Secret Access Key - 1vSr3CTYnXvRsDCAJJovHhgEt5EkvdbUedysI6lX
#   Line 36984: Secret Access Key - t4YkOxUbfzxaAC77n9N9qSeEExztvcjA1JLS/pub
#   Line 37006: Secret Access Key - dev/andreacoelhoadvogadosfddefer44343434
#   Line 37008: Secret Access Key - dev/dxsc9hsjcbnjcbn3ur9fejcxbjcbjdbc39f9
#   Line 37008: Secret Access Key - wsocjlkxzsjcknfe3hry38trgfgdhcvbhxcb3r8r
#   Line 37008: Secret Access Key - hfdsihcijknjsxcn392dhwuscbjbcn38fhyjucbs
#   Line 37012: Secret Access Key - 1vTWx1u8uW24ZnpgEir51AYsnRs2bxeZvlY3AvAD
#   Line 37014: Secret Access Key - lyXTY1oSgaKPOBVa89jHpk1ed28QB92WGe3XBkF3
#   Line 37018: Secret Access Key - mV9wrhC7EX7kcEIgqSsxsLUuMzXCB3gI4Pfx5lGy
#   Line 37023: Secret Access Key - 1vQTNlOI1X3Ll501NQeqjTwuChJYsRtzMkTRHg7q
#   Line 37024: Secret Access Key - 1vR1zDx8dFKtNLAzk1dwSEgDAR9aV29Dnfp5KvXg
#   Line 37034: Secret Access Key - 1vSZzL4YqDhCKZxwCPWsr8ehi8oLs8WG56bG2oqp
#   Line 37034: Secret Access Key - t5biisk1ehlRIXt62xLRLKQhbxS7fiPhbUnQUKmS
#   Line 37036: Secret Access Key - zSDu4v9zJZiDRGbGHxGUbCJkTE9NCylD5ezNmI5f
#   Line 37037: Secret Access Key - DSCdQm9VhieKRlcQK0pTct4SxDnskyr1gxobNzog
#   Line 37050: Secret Access Key - 1vSl0hugeNStX5SU1tMyelTcvmPVzWN3uUavbZLT
#   Line 37050: Secret Access Key - XKpHmpXC6ltt4yJNe3u6yIsCXKzKlnP7tvGPFwGz
#   Line 37052: Secret Access Key - PhOg0RHF0U0Uefd6M1YgxkMFez6Dp3wDvHNs9AT1
#   Line 37052: Secret Access Key - Hl55y7BiTqbQ6VuT0PFSb2wGT98FbBfHDclx/pub
#   Line 37053: Secret Access Key - 1vS9PoMfwIzXPzXL6xae6TRLJvVGklRXUiNm8s6s
#   Line 37056: Secret Access Key - wXN6OTelC53Hz8XU61QWWZAA1ESbZFv2NhLR/pub
#   Line 37090: Secret Access Key - 7weQOE6qdSfTcIMJgUPl61km3WBH2meHtnJjNckp
#   Line 37091: Secret Access Key - yWkqNPD1BuOFnnudBFSoBqABZRDam5b8V6zAPdFU
#   Line 37097: Secret Access Key - 1vTAjonXeNhwksDfaoMc91zr80evbeMKErydlcEH
#   Line 37097: Secret Access Key - qyzUPdSwBqnaLElo38m5gL0mUkFXIgTtINX62Tmn
#   Line 37099: Secret Access Key - RJJdA7B8sWkM51uTczyDiVablk0hGkUWSTK7ifjt
#   Line 37100: Secret Access Key - RJJdA7B8sWkM51uTczyDiVablk0hGkUWSTK7ifjt
#   Line 37101: Secret Access Key - PAsp2fGlrbuLmR0cxWAN40WhartSDrXiNxZXgLrk
#   Line 37102: Secret Access Key - g8Ik9LqX71ZtmB8QSRw3SJ6KBExKs63RWDbFFL3w
#   Line 37109: Secret Access Key - RQzgTtYCKDAOWNr80As8XC0NMhngMrUcCXFg/pub
#   Line 37110: Secret Access Key - 1vS4isfnnru0XcXU0RbOobauWrQKCL4RcXM9aKy4
#   Line 37114: Secret Access Key - 1vSFEWHqXBsSLCWbK4mFQXaSSeqDzkqQ18pkzdj8
#   Line 37115: Secret Access Key - 1vQ6WUjyPS5bX2dFCr7ysCBAzuLeo6z1NYbhzHhn
#   Line 37115: Secret Access Key - pjeeWGtQn5yGxNrudQlulqyJp2477qnc7iHTRpwS
#   Line 37121: Secret Access Key - dev/sidAAQkADZiMjRkMmYyLWY5ZDktNGEzNS04Z
#   Line 37122: Secret Access Key - 1vR6xwMNXY2hvxozyar2vxlXFP7Zx1CgkLR5iYXd
#   Line 37122: Secret Access Key - 1kcCguGRHMQ3LG9qNtqUzPQhrs42YRTcTaQX3R5L
#   Line 37123: Secret Access Key - u3zSqxypDcEVfEYhqrEyd1338TFTdIhNDMmHL1Ba
#   Line 37127: Secret Access Key - kMD77etZUMPFSWKmr3aebEbEn41DVxi3kIWNhyya
#   Line 37128: Secret Access Key - 1vREmnhEZvHgxVFaUShhJji1MoAOMUX2KUS7fM7V
#   Line 37137: Secret Access Key - PAsp2fGlrbuLmR0cxWAN40WhartSDrXiNxZXgLrk
#   Line 37138: Secret Access Key - 1vSK61wi8qEuQs8BRAjxqDPJINGP9nTsWXv6XZlA
#   Line 37139: Secret Access Key - com/forms/d/e/1FAIpQLSf8Yt7vFfrJ4xtBC3nr
#   Line 37140: Secret Access Key - T7WHeWedZmePD5rJPob6FwryXlyMDFVOwq50UGn5
#   Line 37144: Secret Access Key - T7WHeWedZmePD5rJPob6FwryXlyMDFVOwq50UGn5
#   Line 37157: Secret Access Key - dev/cf4t65hfgb89oippopopoppngngt5y5fdvff
#   Line 37157: Secret Access Key - vhny55yfbvfbt66u63fd34efcdgtcbfb66hfh66h
#   Line 37161: Secret Access Key - 1vSrIw1vj9FRN8cdIORZk0cAqwyFZNmY67zv031k
#   Line 37165: Secret Access Key - 1vSd5pErPhraqpj12UAgaNHXxvY30bDOz8l7jaXG
#   Line 37167: Secret Access Key - 1vS6wE1k7gGT17dWCTMtDRxD0hf4xQWa0SmTR2HT
#   Line 37167: Secret Access Key - AVhBNcLlcGnAmVvvi7169MV3BtQOQEGWb0TYf740
#   Line 37168: Secret Access Key - 1vQGTkBIA0od4nYayTT5epQgmNHNVwAuZRoOfSz4
#   Line 37169: Secret Access Key - 6WIilTOK49bFRzr0gESOn62d8UHaJT7dUTZO5ANt
#   Line 37176: Secret Access Key - 1vT3IruTceonZP5wd00sDnigvF3e36XKRvkCXlBO
#   Line 37178: Secret Access Key - hYSPhusznIYhhh1DygSxFHY4pZq4Sqb43g1Pdv69
#   Line 37182: Secret Access Key - 5ip06ywLwakTokD7j3Atb8YYcj7Cm12fItgx6Jvf
#   Line 37185: Secret Access Key - uI6L0398Q8Yw4C1crmmqZ4uk3WbV002XzHaAa0oG
#   Line 37186: Secret Access Key - 1vRDTuMfOPWIJbzTKntkXJyRku3SEnitVEY3sTcH
#   Line 37193: Secret Access Key - 1vRwkAgxaoMYvpEbTmjuwLmHrgSxjg1zwpKJqRUN
#   Line 37193: Secret Access Key - bTCKmXmQ6n8x9tUxGiL41jyYHdIeU3EGxccKx6Me
#   Line 37200: Secret Access Key - o5jLNKcI5BWT41XJ4MXESOkzEi7517LJTXIVx4SU
#   Line 37201: Secret Access Key - dev/8ns63ebddbdbdd737u7ksksmns366522vsdb
#   Line 37201: Secret Access Key - 20d73763353vsbs87382bdgt763bed73g37ebds7
#   Line 37203: Secret Access Key - 3DO4ECJ6p0xWACZ682uuprWTONODWQLedDqjE4My
#   Line 37204: Secret Access Key - 3DO4ECJ6p0xWACZ682uuprWTONODWQLedDqjE4My
#   Line 37206: Secret Access Key - 1vSm2eFgDAZ8LEjT8PGnx30JhSmZNAsCdpvBRAX5
#   Line 37208: Secret Access Key - 1vQnRBh5YYsV5bp8SfaIfmf8bhmlQx3QkfObx20K
#   Line 37216: Secret Access Key - eh118O0r5keEiWAWcUtZ4LhY4XMXXRV1w9XxchLd
#   Line 37218: Secret Access Key - 0DOMvhDfesJ3HPZIyC8rilaIUVIXRtCLnE3bF8gB
#   Line 37219: Secret Access Key - He3wkezPTV52eZHTAXmeW5abhtUjGcfrdZjP7fGh
#   Line 37220: Secret Access Key - n45pAzAw5n6AQLlDNqKbypcRDnI0eNSWyk4XrQjZ
#   Line 37228: Secret Access Key - jCxT1yyoDqEALGf9wnhRoL8sbQx7n2wVDfgAhuAh
#   Line 37229: Secret Access Key - 1vRwkZUozz7XpqMemqhTEHPHcqmdgf87R5UlbjM8
#   Line 37233: Secret Access Key - 1vTFKefvD1ECTkjHa4QpebNJ5oOonv574dbfRDKo
#   Line 37235: Secret Access Key - 1vTWx1u8uW24ZnpgEir51AYsnRs2bxeZvlY3AvAD
#   Line 37240: Secret Access Key - hDlGemUejf92UQUmLbGq0jTvafDJ4vmL4xsTBugB
#   Line 37249: Secret Access Key - webmail3ba649befbdab56fd97e88dea056d8851
#   Line 37249: Secret Access Key - ac761d20e72211125fb28dea056d8851ac761d20
#   Line 37249: Secret Access Key - e72211125fb2ea056d88518dea056d8851ac761d
#   Line 37249: Secret Access Key - 20e7221118dea056dhu851ac761d20e72211125f
#   Line 37250: Secret Access Key - in/html/BQACAgUAAxkDfZI0ImYVx8H3l9MLVmZ4
#   Line 37256: Secret Access Key - 1vTf7LOSQTyXNeWsTCNHmWp4tF7woOHz2bo0HRBE
#   Line 37257: Secret Access Key - 1vTf7LOSQTyXNeWsTCNHmWp4tF7woOHz2bo0HRBE
#   Line 37262: Secret Access Key - 1vTAb1yJtpBMkqkdA1HeJJdRHzH3siYGGkvQXWYU
#   Line 37262: Secret Access Key - qr78VSDrxvSfrANhYkocm6jLXu90OSMAcnEbT7/p
#   Line 37271: Secret Access Key - 7WesvotYxijqpMZNotOcs0LPUdOKIlaS4XG4uZZu
#   Line 37274: Secret Access Key - 1vRXer4fYmM5Nzvvv2X7ARefyay5KD0wsr10cPbN
#   Line 37284: Secret Access Key - D5xIZkOg70JEWP2KOt3tYZhlYdDCiVeToa4G3oWO
#   Line 37287: Secret Access Key - xw7j9OnYp21khr1nBIwYA3n6NkOinSBQfEdxxiGo
#   Line 37293: Secret Access Key - 1vR4qfztxdzvmGilEyAl2MRwhqJGfCXJW3uaeSYJ
#   Line 37293: Secret Access Key - mwNUFgx10W2B9FU7kntAy1kA6eqenJ304sDsTGe/
#   Line 37294: Secret Access Key - 1vR4qfztxdzvmGilEyAl2MRwhqJGfCXJW3uaeSYJ
#   Line 37294: Secret Access Key - mwNUFgx10W2B9FU7kntAy1kA6eqenJ304sDsTGe/
#   Line 37297: Secret Access Key - V2nwbUXjwCGgKCAyVBm7WvEIQXxhmLQmIgxGnCXn
#   Line 37298: Secret Access Key - 1vRNLDJqtm09ma7LgDUzOi7NftX2KxafHBJWJXWq
#   Line 37298: Secret Access Key - 5x7GNirT3JWCkNdsyqRD4fzszaZwUaKn6UaQNMJh
#   Line 37299: Secret Access Key - 1vRNLDJqtm09ma7LgDUzOi7NftX2KxafHBJWJXWq
#   Line 37299: Secret Access Key - 5x7GNirT3JWCkNdsyqRD4fzszaZwUaKn6UaQNMJh
#   Line 37300: Secret Access Key - 9UHhXlzlcoU8QtSzGrPciI8jyxx88ffRUwpbx5a5
#   Line 37301: Secret Access Key - vQpgHbef4SiMfGp4H6Hrr9SkFxSGE58lZUVtzIOD
#   Line 37302: Secret Access Key - 1vRxqvDnSCNetPtUziUrZ4e2RKZSeWDAUwiljKBJ
#   Line 37302: Secret Access Key - Su9krz7OUJ2M9PK4k9o7mJTJy0FG5fYxigIzs/pu
#   Line 37303: Secret Access Key - gpjJrDvb13TtJ2wZPT0xtnL3i9bcOctAWFne5lL2
#   Line 37304: Secret Access Key - D5xIZkOg70JEWP2KOt3tYZhlYdDCiVeToa4G3oWO
#   Line 37311: Secret Access Key - eh118O0r5keEiWAWcUtZ4LhY4XMXXRV1w9XxchLd
#   Line 37314: Secret Access Key - SDRAYiuxaUdmHbxPg6Gg81INV83FWmlbCptLQJ37
#   Line 37315: Secret Access Key - 1vQ7UA37nsBjOPFk9iWdNERbHe2RpNgqL1cqH8xH
#   Line 37315: Secret Access Key - dQTm9ycwKgHzVEcFX3oFRaq8CBgV0pr4fLg1q/pu
#   Line 37316: Secret Access Key - Q1nsnecbirjywuMpObr5xgIy5AekAqP1iPou8t05
#   Line 37319: Secret Access Key - 1vQQTRVpW4yqfPYTjoj369FwdrUj2mkHtlA2CpMW
#   Line 37321: Secret Access Key - p8kpKV7fGZSyQHdNWv5dQAREaErr3hbZqPA7F24t
#   Line 37336: Secret Access Key - tYjDkFWXVblxEkIT8IjzowtDPzQTsnHYIMIrxImv
#   Line 37339: Secret Access Key - nb6D9WbmcziRLSMH406QBKeoQ7ci5qwsM77MpAl6
#   Line 37341: Secret Access Key - cGCP8YiA8wPEmOhU98Tefq3KOO3A49lnP4xK6FTR
#   Line 37346: Secret Access Key - dev/1nbdbd73487ghssvsgv37673hsbsvbs623w5
#   Line 37346: Secret Access Key - scfsvgb87383whgsbsuy7368shgbsb838262rsbs
#   Line 37354: Secret Access Key - 1vSUBets4cL4d4SwC6ELjEzRmurlfkR4e8ujxV6V
#   Line 37355: Secret Access Key - b748fX8OXnGHp3D27RZvkfas9MOXZBZ7EzL0Q5Ph
#   Line 37357: Secret Access Key - CXnrFbvfhdgV6AoyjHtJMcVSSwz5N4mjjdUbWngk
#   Line 37358: Secret Access Key - Plc8edvsOmll8W3HaXvBOtQKyIbQ8mJMrASteBB9
#   Line 37360: Secret Access Key - Gg7lVt0V97czh5i91jCQjDFp1JR8QG8i7klcgWlF
#   Line 37362: Secret Access Key - 1vRQNAZThZxNs3r1XJJ7d7UCq6mA1vKTRyW1EKRe
#   Line 37362: Secret Access Key - csnD82AkRBPXIMc4QtNLAlYG4zax7nVKtWFl0a2M
#   Line 37363: Secret Access Key - eGaJYIFUEEr0nJrTAFQ3hXZybkXpbopZEgvc6yMB
#   Line 37369: Secret Access Key - 1vQKmgtPMgciitX8oSBpz3lxRSSJu8Yfa63eTrHJ
#   Line 37370: Secret Access Key - br/hf2be649befbdab56fd97e88dea056d8851ac
#   Line 37370: Secret Access Key - 761d20e72211125fb28dea056d8851ac761d20e7
#   Line 37370: Secret Access Key - 2211125fb2ea056d88518dea056d8851ac761d20
#   Line 37370: Secret Access Key - e7221118dea056dhu851ac761d20e72211125/er
#   Line 37377: Secret Access Key - //bafkreihbuaki4ahvu2skacwydrjhqr2sjknwx
#   Line 37392: Secret Access Key - DZEHCxFHCEhewPdxG27we5da8LM2z4IQHr21DHEF
#   Line 37393: Secret Access Key - 1KrNnwLnpQBiRk9h6Sok91kTZ5Dvqip05CLC3tvS
#   Line 37395: Secret Access Key - Plc8edvsOmll8W3HaXvBOtQKyIbQ8mJMrASteBB9
#   Line 37398: Secret Access Key - GKnyFcUYOVn3UXTx0uKEat09LSHTqt3y5TMZNX4/
#   Line 37408: Secret Access Key - 20xghgsujhjoljanjhvhjhxjkjsjhvvcccnbcjys
#   Line 37408: Secret Access Key - fgsyfsgusjhsysftwrwtdafacfghajhaajuwywty
#   Line 37408: Secret Access Key - msbscgafaghaahjhwywwwwwtwfwssgssgsgssgsg
#   Line 37409: Secret Access Key - dev/M2ZkM2Y0LWFjZjctNDY2Zi04NWVhLTAxYjc2
#   Line 37412: Secret Access Key - RMregttbBdOxhULGYyXWM69S85M7IHsXlW0CBLw/
#   Line 37413: Secret Access Key - //bafybeicdaibqcinsl5c2zhd7jgycr5pefqe3b
#   Line 37415: Secret Access Key - 1vTYSo9PBzapcv1na7TRaS6HUmx4CMltUwa8dph1
#   Line 37416: Secret Access Key - PakjxTcc4WaxgJz5DM0Va7x6Qcp7277XGAi63Ejj
#   Line 37419: Secret Access Key - OhDsEdI71zUNNmto4RlrcMrTamRKY2vjbns0JdzQ
#   Line 37421: Secret Access Key - WjSC2LcjW3uejPl2OtqjDV9qVPpnKau3z0qmHf6L
#   Line 37424: Secret Access Key - cos5IMK8yPQnFkd5FRuWTfnFOit9fTBnEHp7VtCc
#   Line 37425: Secret Access Key - 0C1CJU6j0SZGgsxgm1eKnXz4WJ5EdSKiCOH1yBzT
#   Line 37428: Secret Access Key - QXQKGNguU1kcKUi73RF2PY3Jq28aOHCUVNd3XY74
#   Line 37429: Secret Access Key - OjIunLA1sxAhgtRb9884SmA10IRcloG3dU6uAtVz
#   Line 37434: Secret Access Key - 1vTtztLUd1KyJI0sYAgcIYY25K867EMATlt4N0sT
#   Line 37435: Secret Access Key - 1vTtztLUd1KyJI0sYAgcIYY25K867EMATlt4N0sT
#   Line 37439: Secret Access Key - com/forms/d/e/1FAIpQLSe8pxCEJZbqc3B7rtJS
#   Line 37441: Secret Access Key - 0KYRXxLYmq8c0deQhBGXNk4We8wkzRFATw7wt278
#   Line 37442: Secret Access Key - 1vSTHMFHpqm4RKkBdfaL5d3pJzd9TOiD8YUVyY92
#   Line 37442: Secret Access Key - 5VcnYLjZB55VZi11JVTeObI7xOFo6fy4q8cd/pub
#   Line 37451: Secret Access Key - 1vRoADlxkkibq7IjZ56vcrZla9Isjtt6TS38B6iu
#   Line 37456: Secret Access Key - 0C1CJU6j0SZGgsxgm1eKnXz4WJ5EdSKiCOH1yBzT
#   Line 37457: Secret Access Key - v9k2gc4snq1QS5pWbYGQYRr9sW15lHrG4WBHs4Fw
#   Line 37460: Secret Access Key - de/pub/forms/f11bec1411101c743f64df59677
#   Line 37462: Secret Access Key - k1akesDZQmpxlhvZEHw3EmwKKdzIec2JcXWQ58ql
#   Line 37463: Secret Access Key - //bafybeib43dvjrbjsgjiqbl5gl732xm2cx3lkt
#   Line 37465: Secret Access Key - 03NmWr1Xjbk5lci9fR9z7XkYeFU77e8ouD1W/pub
#   Line 37468: Secret Access Key - //bafybeifcfe5xorgq2rm5cwebwgksa72gyifrf
#   Line 37469: Secret Access Key - //bafybeifcfe5xorgq2rm5cwebwgksa72gyifrf
#   Line 37477: Secret Access Key - br/hf2be649befbdab56fd97e88dea056d8851ac
#   Line 37477: Secret Access Key - 761d20e72211125fb28dea056d8851ac761d20e7
#   Line 37477: Secret Access Key - 2211125fb2ea056d88518dea056d8851ac761d20
#   Line 37477: Secret Access Key - e7221118dea056dhu851ac761d20e72211125/sm
#   Line 37478: Secret Access Key - br/hf2be649befbdab56fd97e88dea056d8851ac
#   Line 37478: Secret Access Key - 761d20e72211125fb28dea056d8851ac761d20e7
#   Line 37478: Secret Access Key - 2211125fb2ea056d88518dea056d8851ac761d20
#   Line 37478: Secret Access Key - e7221118dea056dhu851ac761d20e72211125/er
#   Line 37485: Secret Access Key - dev/86gfg6ii9997fgfewr55646fgdhu65868969
#   Line 37485: Secret Access Key - 96wrsfsdfgt768gdgf3r5wefe5y757gfv3645tgf
#   Line 37488: Secret Access Key - dev/Anaylayowbhsn78904u8y2hubjwnbdjnksml
#   Line 37495: Secret Access Key - com/clientportal/Conferences/Registratio
#   Line 37500: Secret Access Key - V0WBaGxgq7AKMjIDL5zFcaMGey2mruamZkEudAae
#   Line 37502: Secret Access Key - 1vSUYFQvvXjsiXAj5uZdJkmWkLEjs63AOIqhbyVU
#   Line 37502: Secret Access Key - JeGZp6iTjsJzZWyGnzitF0Zgdo5QvUhULgw2Tlb5
#   Line 37503: Secret Access Key - G4YAQzTBbUM7fBKK31Cev8ZtGipLO8tzTsPt/pub
#   Line 37505: Secret Access Key - 3tng9vrEH3Xc1ZQxOuQKHjp8QE9EidW4r9sKU7vV
#   Line 37506: Secret Access Key - u2yUBmlJ1m2ssKdon0fZ0w8WR3QtSOHgVDi9dHD6
#   Line 37507: Secret Access Key - sGDmecVbaTmyI9DzQUhgvwTYU82FXSb2eEYGfrE0
#   Line 37511: Secret Access Key - CBzQ9Rws4MTYcURwVf9hC2FpMKNASbMjShcH9ck4
#   Line 37513: Secret Access Key - gYmEYXDqkSCb5usUCqSYx4gGKFv8aCMQbejKqK2G
#   Line 37515: Secret Access Key - 3tng9vrEH3Xc1ZQxOuQKHjp8QE9EidW4r9sKU7vV
#   Line 37543: Secret Access Key - dev/GHvjg7Vgyy7Yg7y7f86DFos8s8GYSYY8sggs
#   Line 37548: Secret Access Key - 1vRm3MVJYnFVkMdWfbF3CbtYurf54hV7qdrb4M0Y
#   Line 37548: Secret Access Key - MaEmYJewDK5WROpvFHUMYuNUtmv259Qy34i9Vs1l
#   Line 37559: Secret Access Key - hOED4Zb7z45UR87o0JoJnUH7J73R9vQ3csrPX46b
#   Line 37560: Secret Access Key - hOED4Zb7z45UR87o0JoJnUH7J73R9vQ3csrPX46b
#   Line 37561: Secret Access Key - oHqdGPUINB2ofnASRlCnkSHq7OgN9YiSYIyIwfMW
#   Line 37565: Secret Access Key - 0pnEmVbaw5jqdhWnhYyRAqcIDtj1wNAE7YXjJK6J
#   Line 37566: Secret Access Key - 1vTHUYjVKziIS5zbb4iDp5xwQA4XyosTy1LLxbQ3
#   Line 37573: Secret Access Key - com/run/kSb64fsgju/p4sshEiaqd/nYwRStJgch
#   Line 37578: Secret Access Key - u2yUBmlJ1m2ssKdon0fZ0w8WR3QtSOHgVDi9dHD6
#   Line 37582: Secret Access Key - gvqS66TmtDBcDRGgQRrMj7cc7Qsc99jRYX35L7zS
#   Line 37599: Secret Access Key - 5okfOJn8cnnHqysjPnVzdfO1AfbBdBCPyNP1G6QT
#   Line 37600: Secret Access Key - 1vRCzZP3UDxbQvgjFyqSsyKEXeYhHF7Evq7eciMH
#   Line 37600: Secret Access Key - 4Oq0i4FvlRjU24PLJzSrNw6wIxaknB2oW9Q0HZz5
#   Line 37615: Secret Access Key - DQSIkWdsW0yxEjajBLZtrQAAAAAAAAAAAAMAAHMv
#   Line 37615: Secret Access Key - vJtUQlYxQkNBTjg0WEFYQVhLQ1JSS0pJWUNaWC4u
#   Line 37619: Secret Access Key - 1vT0E0rxMyPfx8UlYfWejnCyKJp4ZI9toEoJdbZD
#   Line 37623: Secret Access Key - dev/kjvfhe9terju9idjitug9erue9rdjhgikih9
#   Line 37623: Secret Access Key - 8rtyidhcjkvxbjhcvhxcfvdgcfdstwtdftszhcbv
#   Line 37641: Secret Access Key - 7LDQhp37vnwen7wA7e7et9Tyap3gfrRKwz5OS1Mi
#   Line 37651: Secret Access Key - wdVfLyWmQTyllKXLQJ7XdbMMFdthpwfaB6FFxWVg
#   Line 37651: Secret Access Key - zMfbOs31Rd84QhgevMWeADQ20rAnqVQFGvSL/pub
#   Line 37655: Secret Access Key - G4YAQzTBbUM7fBKK31Cev8ZtGipLO8tzTsPt/pub
#   Line 37656: Secret Access Key - 1vREw8p3RAp9gClsxGRJiCXdatAW9Mh4KidSw6hp
#   Line 37658: Secret Access Key - lVSqdGZWoaSRudYrsSADBWflUv9EgBCWdNs3EZlB
#   Line 37662: Secret Access Key - 1vT0E0rxMyPfx8UlYfWejnCyKJp4ZI9toEoJdbZD
#   Line 37664: Secret Access Key - //bafybeidyrnwtlvlhckl4cdut23ob3dnyodzyt
#   Line 37676: Secret Access Key - com/run/kSb64fsgju/p4sshEiaqd/backToHead
#   Line 37680: Secret Access Key - aop7SlvoPxhhoWiEE433eFkeEzBLM5AvQtrVvW8Z
#   Line 37683: Secret Access Key - 1vRkh1Rzp6P2CcA3NNGTO1P0vIqgXghWT8W2IbMq
#   Line 37683: Secret Access Key - raHjJOxfj8jsJB8jf1PwJakfle8TonvbOmvhFuv9
#   Line 37684: Secret Access Key - 1vQu3qE2eFSpdh84GaAEsZPIuE7k8lE9manpzxv5
#   Line 37689: Secret Access Key - lQYTBIMmniNKO0Wghz57zKMrx5ze3HbTCdO4NeXw
#   Line 37691: Secret Access Key - 1vQ953e4mjl2dI3BXvGCOmVWWht7lXNhHKkbdm0x
#   Line 37692: Secret Access Key - Q2vvhVTB39tzEB2r5Og1fshl4VLJ6TmDKOF0qn4X
#   Line 37694: Secret Access Key - nYma7pdJ8sCstXJ8LwhHlA6l0tqCjR9F8uOOzcXK
#   Line 37708: Secret Access Key - 0pnEmVbaw5jqdhWnhYyRAqcIDtj1wNAE7YXjJK6J
#   Line 37711: Secret Access Key - io/ipfs/QmWikvJg8nefnh79V3fr8nZqYTE2jSri
#   Line 37712: Secret Access Key - io/ipfs/QmU7ZKVQFcCHCfG6TtzTG3UpLQSshWns
#   Line 37713: Secret Access Key - io/ipfs/QmU7ZKVQFcCHCfG6TtzTG3UpLQSshWns
#   Line 37715: Secret Access Key - io/ipfs/QmavRvsah8mGoyrmGoMv4Jrs6LDhbnUm
#   Line 37716: Secret Access Key - com/private/95F758DD75E/bt0987654567mail
#   Line 37717: Secret Access Key - jPYjOOF1KnsDEmw0srYUQi05wKP7bFLqLXLzZJeE
#   Line 37719: Secret Access Key - io/ipfs/QmcpZ5YggsLHG7YGGmH83ejjjzaMf65M
#   Line 37720: Secret Access Key - io/ipfs/QmcpZ5YggsLHG7YGGmH83ejjjzaMf65M
#   Line 37736: Secret Access Key - 1vTEfoIRk0oAL3BktMIpMuWcukeQ7VADoSqRj53x
#   Line 37736: Secret Access Key - sizf9x2GtJ7lDo6m4PwIQL4zSDulVZzFr4Jfg3Vr
#   Line 37741: Secret Access Key - V0WBaGxgq7AKMjIDL5zFcaMGey2mruamZkEudAae
#   Line 37743: Secret Access Key - lVSqdGZWoaSRudYrsSADBWflUv9EgBCWdNs3EZlB
#   Line 37745: Secret Access Key - UAoyJIar8FGW5qMJDl9zcmnSkxxbndNc00UrDPKC
#   Line 37746: Secret Access Key - V0WBaGxgq7AKMjIDL5zFcaMGey2mruamZkEudAae
#   Line 37747: Secret Access Key - G4YAQzTBbUM7fBKK31Cev8ZtGipLO8tzTsPt/pub
#   Line 37748: Secret Access Key - jQef5tzGc4JWSkEGIqXfKdSOh8l1293mYcOQnqoL
#   Line 37751: Secret Access Key - 4JPjUs0rd4PISIwsl5diGRacUZDmpXzVFHV7iJf0
#   Line 37752: Secret Access Key - Mvh1VnX5L7E4hdFmCO8ogNo5Nuqn3WmZzGVLbh5C
#   Line 37754: Secret Access Key - aa5cc43015815732a4d38f73eec6434e3e5cc430
#   Line 37754: Secret Access Key - 15815732a4d38f73eec6434e3e5cc43223401581
#   Line 37754: Secret Access Key - 5732a4d38f73eec6434e3e5cc43015815732a4d3
#   Line 37754: Secret Access Key - 8f73eec6434e3e5cc43015815732a4d38f73eec6
#   Line 37763: Secret Access Key - anHqmpmtkV9q5YqLhPz9fYKRqui33rfJDTiBumKE
#   Line 37764: Secret Access Key - 1vS5HXyPnFNjcQ43zc1ZTYOodNQV8g8IQQoTlWMC
#   Line 37764: Secret Access Key - KdsXUpY5i5UPVO0PYgXPAWdKgmvvqtmsK05Bexht
#   Line 37788: Secret Access Key - 1vTBfMPjVb8Gdtkxj6HkcCJXBdTkrF3k7EGxpqwS
#   Line 37789: Secret Access Key - 1vSVtLdSe5nkkotAbLZ8oOUpWqGbrPpe3Ae6nzBK
#   Line 37801: Secret Access Key - tUUHXI9HT9rb4PZJbnY7l811soR7NL4tW5hCfPXo
#   Line 37805: Secret Access Key - 1vR0nWq5n5ptx4Wjrs2jt2nKt8M56bHkoBcneePo
#   Line 37805: Secret Access Key - agzC95bvaIfvlIoQajsO5e3zcrr3NdNxU2wAUp2E
#   Line 37806: Secret Access Key - PSdvd8bzMnMermQ2WIjrYumv5lWDxLK5rMFSkO73
#   Line 37807: Secret Access Key - 1vR0nWq5n5ptx4Wjrs2jt2nKt8M56bHkoBcneePo
#   Line 37807: Secret Access Key - agzC95bvaIfvlIoQajsO5e3zcrr3NdNxU2wAUp2E
#   Line 37811: Secret Access Key - xZtXBNJ6bgH7w6PEu9ZiVSPMWKJls5Kl52aijLLt
#   Line 37812: Secret Access Key - 1vQYLrA6FLFT4b2dOcFrA48Oo8YnRUgvxIWcPzwW
#   Line 37812: Secret Access Key - dnWBFeq8SXt4kTMzgF9MdzkwK9o5cZWw5XmIK65U
#   Line 37814: Secret Access Key - 1vRALzCpBQYOY3FvTcJjVLK3QryuLk8luSPNc29p
#   Line 37814: Secret Access Key - kNVaibrNNnPrRaSDUfAQMNc5KnRIxUqkCnJfxEAw
#   Line 37816: Secret Access Key - DQSIkWdsW0yxEjajBLZtrQAAAAAAAAAAAANAAVwz
#   Line 37816: Secret Access Key - umxUQzdNSkZMVVZJRUlBTlNUOUQxVDlMMVBUWi4u
#   Line 37817: Secret Access Key - 1vTZDeFnrYkWEqM7WCZyqg5zdxzRylW0QdUiEcGj
#   Line 37819: Secret Access Key - 1vQN52AeGLvK77p6LyXsNcctpJrAe7Vvepyx8qLZ
#   Line 37819: Secret Access Key - jE3fqQXKoGyNomWiXbzN9BvlSkRnHFF0viu85hh4
#   Line 37827: Secret Access Key - awesome/css/hereme/116645/77685r/bWljaGF
#   Line 37828: Secret Access Key - IgUwVtCPvVoY5VoT1qxMhbJUhwTJTv0JAeaN598J
#   Line 37837: Secret Access Key - 1vTsLv0GGHwNEG7ccHCSyUuIe9YjQJGkwtn6uADP
#   Line 37837: Secret Access Key - 6dMgDNAmXw65qBrv0t0WKDYFZvOK0xDwTGURSEXx
#   Line 37838: Secret Access Key - H9DHoIsSZL79UEe2m80LACd2gM12NNteF5ugtvtm
#   Line 37842: Secret Access Key - i36Sg0Mk0Jma3Vie13u13BQtWzh77N4eYu0zGFw5
#   Line 37842: Secret Access Key - klnyXv7OfC3hlNUcFlThHNaZZbun5OcQPMmd/pub
#   Line 37845: Secret Access Key - 1vRudjw2xpsuOW0xC9QUqhYNe8ZKz6ZFOBsGDnqE
#   Line 37845: Secret Access Key - X7eoWx64BO9gWCwTh8cQo2ayG756XRNJbaehOi0e
#   Line 37857: Secret Access Key - 1vRk4Dp6fWdWZLaR4sdhTNtgOe41GbCWsGJtKCgN
#   Line 37865: Secret Access Key - Rwz5tcUWcXPKoxUyMUzWQ5XG8oQW1h2Tr4e1FfmW
#   Line 37865: Secret Access Key - V0E4VG9c24hMIghH0YQPwbzqjt1pFImZWcMjKB96
#   Line 37865: Secret Access Key - 1RlOMlJrCnp7VN0QFPlg0RdzHkTRv1Uig8D5Kwra
#   Line 37865: Secret Access Key - od7MnzUtV4xfsJUYprkLfrHp2oa5YXHDKSNP2eVy
#   Line 37865: Secret Access Key - oDVCbGM9S8pT2dvAYldEXFlGMcbNb5f8RmyScor2
#   Line 37865: Secret Access Key - 0DwdJJBF1elUOeIXeeZ2Ib1nqr0QVxcsEbNEFiIN
#   Line 37865: Secret Access Key - Bu2Sy8FNflAok9OpDYwDeifoOvrfJRDqy5NInsT0
#   Line 37872: Secret Access Key - //bafybeicmyst2plbqaru4fbrkm6jivmyly7tbf
# ...
#   Line 50167: Secret Access Key - se/ipfs/QmXV3LeA2iFpXCyLk7Kh1xVUNrztNciB
#   Line 50169: Secret Access Key - se/ipfs/QmXV3LeA2iFpXCyLk7Kh1xVUNrztNciB
#   Line 50181: Secret Access Key - //bafybeiekygh2vxzltltdxc5n4crr76bmrlcv7
#   Line 50181: Secret Access Key - 487f7b22f68312d2c1bbc93b1aea445b487f7b22
#   Line 50181: Secret Access Key - 487f7b22f68312d2c1bbc93b1aea445b487f7b22
#   Line 50203: Secret Access Key - 1vS5u2W0nfAhCcNV1yhv5RoALDT4j4QfTtKVCGpg
#   Line 50203: Secret Access Key - zHY8rZ6iwtw2i8um0FPb56igbPK68wTCZlLWPpQa
#   Line 50204: Secret Access Key - 1vS5u2W0nfAhCcNV1yhv5RoALDT4j4QfTtKVCGpg
#   Line 50204: Secret Access Key - zHY8rZ6iwtw2i8um0FPb56igbPK68wTCZlLWPpQa
#   Line 50205: Secret Access Key - 1vS5u2W0nfAhCcNV1yhv5RoALDT4j4QfTtKVCGpg
#   Line 50205: Secret Access Key - zHY8rZ6iwtw2i8um0FPb56igbPK68wTCZlLWPpQa
#   Line 50218: Secret Access Key - se/ipfs/QmXrRB1QHJKxuXaBcxiUEAAXZQ4DiNSE
#   Line 50225: Secret Access Key - 1vTiTDgBxJJHypQUFgpWAslFMUepn3ZNv8JdNGxu
#   Line 50228: Secret Access Key - UDjxT8YOjW9dt7bRPCNbQbfDarE13pqu8zVibzWi
#   Line 50247: Secret Access Key - com/forms/d/e/1FAIpQLSf6PnQX1HMG6p62iHlA
#   Line 50248: Secret Access Key - com/forms/d/e/1FAIpQLSf6PnQX1HMG6p62iHlA
#   Line 50250: Secret Access Key - com/forms/d/e/1FAIpQLSfxEjMGQxHHP9GpTO85
#   Line 50254: Secret Access Key - com/forms/d/e/1FAIpQLScdsBe4u7ia8BS8umEQ
#   Line 50255: Secret Access Key - com/Ctc/GH+113/d39Wpm04/VVRjGx8Fp89SW9dl
#   Line 50255: Secret Access Key - W4bc4Rh9b7HrTVNNTmk8LRM02W78M82Z6YvRTWW2
#   Line 50255: Secret Access Key - qFW2XWQQ97pHYXjW2xWz3B5JPRZgW383rwx5lwqt
#   Line 50255: Secret Access Key - HW59ZTxc5WWZQcW54bGCL1Nw5sXW5RQQN049Kyl1
#   Line 50255: Secret Access Key - T4VN4DvnCYW44N4W6tjKjz6rpNF0VlYchH1FZgTF
#   Line 50255: Secret Access Key - dLLMW7zXzmJ73hMD2W8XMwJ15G33BDW4L3zSb5sR
#   Line 50288: Secret Access Key - 1vQc785Z3dP5aflpwHe9KSmTaLic6K1I0dBKMUlJ
#   Line 50292: Secret Access Key - Ste6htrpi38VHIPIcNKi1RbDC4P2cxWnSNqGl9dM
#   Line 50305: Secret Access Key - ahr0cdovl2rvbwluawsubw9uc2lvbc5wbc9tyxjj
#   Line 50305: Secret Access Key - aw4va29udgfrdeblc290axeuy29tffltvxlnaljs
#   Line 50305: Secret Access Key - ttjjeu5estnzveprwlrzee1uzghpr0zrttjnme9e
#   Line 50305: Secret Access Key - bgxar1zbzedomwjhbdfiuzv3ykh4vwfivxnjree1
#   Line 50305: Secret Access Key - suuxagnpqxlnrel6surbm09qrxdpaluwsunzd01u
#   Line 50305: Secret Access Key - qxdmr3r5wlc1cgewqmxjmjkwyvhfdvkyoxrmrev1
#   Line 50305: Secret Access Key - wlhodmrhbhhmbk50zehcogntvmtam0pwwkrjmwze
#   Line 50305: Secret Access Key - qjhnuzqyt1rnevluzgxnemcxturnnvpuaghabu01
#   Line 50314: Secret Access Key - com/serve/MUIEAHhMYENCcIPh6PzZeZPAEgwpQS
#   Line 50314: Secret Access Key - Vo2Nbq089yxhyTGEF7g2gnPWM17LgLYkcc914de3
#   Line 50314: Secret Access Key - 22hieMGfFwFiXdmKlkcQu5DZHWhjZDsGhokg0zNx
#   Line 50320: Secret Access Key - se/ipfs/bafybeifgcx3ob2bhl3tde3dfdz3hoku
#   Line 50349: Secret Access Key - com/serve/MUIEAE8MqJDDSysttcjDeLwiptyzf7
#   Line 50349: Secret Access Key - nlTsCzxUo2m9OxQbOCC6UUmLueDLgiqUtwUsRk7j
#   Line 50349: Secret Access Key - PM3wNtL1QDwGkhOilKYCoJbVo0BHoLKR8cjYMqPw
#   Line 50369: Secret Access Key - a4c4869e2c8dbef7JmltdHM9MTY3ODA2MDgwMCZp
#   Line 50369: Secret Access Key - Z3VpZD0yYmRjMjRjMS1kNTYxLTY1NjgtMGVjYi0z
#   Line 50369: Secret Access Key - a1aHR0cHM6Ly9hbmdsb2tvbWJsb2cuY29tL3RhZy
#   Line 50373: Secret Access Key - zgu33n4FCatF7AF2c7cN4JvsfcTGUo5Ts5Yi5pUP
#   Line 50413: Secret Access Key - //ndjqweke9283893emwmw839203fdkks8493jds
#   Line 50474: Secret Access Key - se/ipfs/bafybeidofxreo4tesjb77gdpsmlb763
#   Line 50475: Secret Access Key - WVPbuCnWXZWTSWNCLBG94VQaf0NvGL1tPHUfEo/p
#   Line 50482: Secret Access Key - 5InxGQC8khRJQ33e0U0Fdnq1m7J1OdH34c93jXuP
#   Line 50483: Secret Access Key - i50BofPXudVBAqEDMcNUDA0ESgFn8qgf6cxhw8JW
#   Line 50499: Secret Access Key - me//////////////////////////////////////
#   Line 50499: Secret Access Key - ////////////////////////////////////////
#   Line 50499: Secret Access Key - ////////////////////////edge37fe4efb73d5
#   Line 50502: Secret Access Key - CH5LWdMUW5FDNt3Gn57ix7KBj8GNHwOGQnEFG7EW
#   Line 50503: Secret Access Key - U6rdlVyTzE49qmgmCxZYpeIxnimQPb6XnJ3mRIIu
#   Line 50558: Secret Access Key - edu/EQS6Ut8UZjVKi3XnhSRIKR8BLhndzaVohrcP
#   Line 50611: Secret Access Key - 871vIKMgfaIB1gKbcvy85hZ3aHIo75Yn9m655CKg
#   Line 50650: Secret Access Key - com/solttitll098/upgrade/newaliexpresaut
#   Line 50653: Secret Access Key - ZcW4Y6XXmWShyhnYOM3vuthMSWv9U9wFDaIm4sja
#   Line 50667: Secret Access Key - gTcAFDbaPRMhDhCpJIq8KHjU762mDTMbJRNIMbpt
#   Line 50688: Secret Access Key - 2f018756269f62c6JmltdHM9MTY3NjU5MjAwMCZp
#   Line 50688: Secret Access Key - Z3VpZD0wYTZmY2JlOC05ZjkyLTZlMWYtMDdjYy1k
#   Line 50688: Secret Access Key - a1aHR0cDovL3c2OWZ2Lm1rLWZsZW5zYnVyZy5jb2
#   Line 50701: Secret Access Key - se/ipfs/QmPLQ96owEfhMTMH5yaPHVKiPGRiygK2
#   Line 50759: Secret Access Key - 2BkudwRXh2uR8XflQ96GBjEtKkOvL4nhMj71rFAF
#   Line 50759: Secret Access Key - wjKW3jsShoU0WAIDG5gujowEq6sBshuCsOUDJmqE
#   Line 50759: Secret Access Key - 2B3qmQbgUxO3uaHX7D2gI2oz41DPp68bqe4fNhCu
#   Line 50759: Secret Access Key - 2FrXSyU8qz2PeLLSa72RSlctM5b0R9cc6vrJvlGw
#   Line 50759: Secret Access Key - QTPA5sEBw8JJjlxm0w4raY43ulknTaya1lv6zckX
#   Line 50766: Secret Access Key - M6AEkmAvVfFTqjXYpMGWyrurYDKHCMBWCauwyMyE
#   Line 50770: Secret Access Key - jwtpp2ELiJFAXfgfBRITG1xRGUFITOHtQWbAuWPj
#   Line 50789: Secret Access Key - 1vTxALAlx9S4EbRRBCzjMDDi6WZIKg2o96udOTNQ
#   Line 50789: Secret Access Key - HryLK1wKsyrI2D5hmh0i6ReCJRKmyjFYCTRxd9tL
#   Line 50832: Secret Access Key - mix/onlinefreeTonline/onlinefree/kunden/
#   Line 50847: Secret Access Key - content/plugins/f30d43ea1d474f2cbb0d9e56
#   Line 50856: Secret Access Key - content/plugins/f30d43ea1d474f2cbb0d9e56
#   Line 50862: Secret Access Key - 6883e0e7529b0ef6JmltdHM9MTY3NTQ2ODgwMCZp
#   Line 50862: Secret Access Key - Z3VpZD0wYTZmY2JlOC05ZjkyLTZlMWYtMDdjYy1k
#   Line 50862: Secret Access Key - a1aHR0cDovL3d3dy5uZW9tYW1tZS5uZXQvZm9ydW
#   Line 50902: Secret Access Key - org/assets/dashboard/img/events/tracking
#   Line 51071: Secret Access Key - se/ipfs/bafybeih7vmipmlhrmnifibc2mraaoxo
#   Line 51100: Secret Access Key - se/ipfs/QmPLQ96owEfhMTMH5yaPHVKiPGRiygK2
#   Line 51138: Secret Access Key - CjwKCAiAoL6eBhA3EiwAXDom5h0PISVIDP5INkpY
#   Line 51139: Secret Access Key - 4zLXRBoY3sT03RTxyP1nx0jQe9fQ3Cm5FBFjbDwj
#   Line 51293: Secret Access Key - zggp91BbFZhdpok4qPg2HCxUtobdye6Y55yTsoFS
#   Line 51320: Secret Access Key - io/ipfs/QmS9bCLi5MGPX2xwz9xCmFh8LFs4fnVB
#   Line 51321: Secret Access Key - //psowwau8292192snamqkq21822jsj8910223hj
#   Line 51326: Secret Access Key - 8977fd0f5207fcb7JmltdHM9MTY3MzgyNzIwMCZp
#   Line 51326: Secret Access Key - Z3VpZD0yMmI5ZmZmNC0yMTZjLTYyODEtMjllNi1l
#   Line 51326: Secret Access Key - a1aHR0cDovL3NhcGFtc291bmRwaHVrZXQuY29tL2
#   Line 51339: Secret Access Key - 36777f107509e830JmltdHM9MTY3MzQ4MTYwMCZp
#   Line 51339: Secret Access Key - Z3VpZD0yYmRjMjRjMS1kNTYxLTY1NjgtMGVjYi0z
#   Line 51339: Secret Access Key - a1aHR0cHM6Ly9zb3ZpY2EtbG9pc2lycy5jb20vc2
#   Line 51348: Secret Access Key - 524bd5c5a916ba95JmltdHM9MTY3MzQ4MTYwMCZp
#   Line 51348: Secret Access Key - Z3VpZD0yYmRjMjRjMS1kNTYxLTY1NjgtMGVjYi0z
#   Line 51348: Secret Access Key - a1aHR0cHM6Ly9zb3ZpY2EtbG9pc2lycy5jb20vbW
#   Line 51392: Secret Access Key - 4584uztu/acceder/Web/Fr/creditagricole/C
#   Line 51472: Secret Access Key - com/forms/d/e/1FAIpQLSckfDFOxF1ACu60cA2n
#   Line 51473: Secret Access Key - AeAAQh7drjOUOqTXIezHUUuazsZIRmXyZf63RxF4
#   Line 51479: Secret Access Key - com/forms/d/1hZSdrc7mwOWsVJOm8VyhSUVobgz
#   Line 51480: Secret Access Key - v9TLPbv7BleWQmBz6OtPMW4TkqaZZBLlOyO8bzAt
#   Line 51487: Secret Access Key - v9TLPbv7BleWQmBz6OtPMW4TkqaZZBLlOyO8bzAt
#   Line 51500: Secret Access Key - 1vTF95xU6fWiDhiEvyPeEOrBIdGQzaLyUBHmCowU
#   Line 51519: Secret Access Key - com/sharelink/w/4hWexsXTBv7eBj9RH3YAKg5M
#   Line 51539: Secret Access Key - com/serve/MUIEAE0e8QhQ5rEQ2oKO1Sqv92pDX2
#   Line 51539: Secret Access Key - vixbh1kRW5uWA9KTu0lu4sO3VzhxDTaKMlEGZa5e
#   Line 51543: Secret Access Key - v9TLPbv7BleWQmBz6OtPMW4TkqaZZBLlOyO8bzAt
#   Line 51571: Secret Access Key - id/templates/beez3/Ziper/pagomente/Detal
#   Line 51593: Secret Access Key - LSX9tJDn0iacUHhb4ABqaGLMDT3zkCm5AdLkDbsk
#   Line 51611: Secret Access Key - //bafybeihtib4k3bls37ymigxqtsa7hchs3yuzn
#   Line 51612: Secret Access Key - 1vQycuDYakIjSaqqm1IZiU3TOMeeSuFZVOHProVn
#   Line 51620: Secret Access Key - Cj0KCQiA1ZGcBhCoARIsAGQ0kkrnOSqncrvnfzK5
#   Line 51620: Secret Access Key - K2m0Ub2hOLATSELPr5hu2VCDGQgM7wfnqmBjwD8a
#   Line 51645: Secret Access Key - //bafybeibfrj37awd4ylwqokptb3oqtaa5wata6
#   Line 51679: Secret Access Key - //bafybeib7qftc7bgvhkdew2purmpqalnn2knkw
#   Line 51680: Secret Access Key - //bafybeifewwiqtog5qg3wdv2tmucylklfebapo
#   Line 51681: Secret Access Key - //bafybeihdar7rztkscbfw2cac2s6pbhsuexzep
#   Line 51703: Secret Access Key - //bafybeibucwomwhuava46rcskf7vp56lb2eeko
#   Line 51709: Secret Access Key - 1vQcGDoC24kqMUcVf22cGd6KSrx4J3bnoc4mCsiq
#   Line 51709: Secret Access Key - OPAQdfT1XOWZlvrFZXCVWqEuo9tDFvZ9w1n4gSE4
#   Line 51724: Secret Access Key - //bafybeifuj5nalym5xn7biif3jhl3rdcdhnmpf
#   Line 51725: Secret Access Key - com/forms/d/e/1FAIpQLScTTyhQ9MBArmjdqgWy
#   Line 51748: Secret Access Key - //bafybeie4pqchsdskydczfwraul6oeggd4bkxa
#   Line 51765: Secret Access Key - //bafybeicx632kovolcmtykzyzsmgbl3uxxxspl
#   Line 51789: Secret Access Key - IwAR3KHtT0r23qtFJArGRtOOwy73SdrMEAZz7FBp
#   Line 51832: Secret Access Key - DHd25QfzAKagFAe6Rc7clXKhZ4Q3tktE9Wg5Mo91
#   Line 51833: Secret Access Key - rii4Zlm5Yg8iR1Eb4en5Ih06k8NJwitVWFVLJE30
#   Line 51874: Secret Access Key - DQSIkWdsW0yxEjajBLZtrQAAAAAAAAAAAANAAUvU
#   Line 51874: Secret Access Key - cVpUQzNGVlY2RTE2MFBWS0U5RDNYREdWTE9RMi4u
#   Line 51883: Secret Access Key - com/forms/d/e/1FAIpQLScmf0uZMHL0RYe3xJCT
#   Line 51914: Secret Access Key - link/ipfs/bafybeigw5jlwvykqqwfwiz7bykja2
#   Line 51915: Secret Access Key - //bafybeigw5jlwvykqqwfwiz7bykja2imjyes2o
#   Line 51938: Secret Access Key - UxHTWzJdl7cW4swDmErZqMWm0R432xAjgh7M68p6
#   Line 51942: Secret Access Key - 1vQpNti3bDqjGbzjWi0ngToJSXmDbWG61NQahtDL
#   Line 51984: Secret Access Key - co/ipfs/bafybeic4olp55f7k6djfpg7atntw4x4
#   Line 51994: Secret Access Key - 8ekpmeFnVnzus4ysUMkOlld3AHGTDYmbUKvVit2V
#   Line 51994: Secret Access Key - htyWaIhF3tmZj0VMmNf4ECTpu08KQC3RjwlkHM7u
#   Line 52032: Secret Access Key - aHR0cHM6Ly9qYW5zc29uZW50cmVwcmVuYWRhYi1t
#   Line 52032: Secret Access Key - eS5zaGFyZXBvaW50LmNvbS86bzovZy9wZXJzb25h
#   Line 52032: Secret Access Key - bC9qb2hhbl9qZW50X3NlL0VvOGx5TzR4cU4xQ3Zq
#   Line 52032: Secret Access Key - ZW5HRzg3Ri00QkZlSWlOWFBjWFp2c0xNcGIydFNp
#   Line 52038: Secret Access Key - OBSKnC9FApRsbcO6MlnhURTNEVVdZUzZEWDdIQ0x
#   Line 52043: Secret Access Key - Z289MSZzMT0xNDcyMDQ5JnMyPTQwNDA0NzkmczM9
#   Line 52057: Secret Access Key - KXBhAaEiwA2RZ8hApoeGm3hfZQQeYM3QdlRqM9Ve
#   Line 52082: Secret Access Key - 1vSrlc9WJgpKksVgPKM5badS0jspilucC7YAyyCv
#   Line 52100: Secret Access Key - com/forms/d/e/1FAIpQLSdbKfmfqZTp7jGOVpCc
#   Line 52137: Secret Access Key - 4y4PfiNcDtzMT6QiM5QfFhFuXcb4Kl4/viewform
#   Line 52139: Secret Access Key - com/link/62ec0819e7239400160765f9/62ec07
#   Line 52139: Secret Access Key - fec03d7d001dc835c5/62ec07eb316b48001c631
#   Line 52139: Secret Access Key - 9914fff38c28a734939ec6ad3c3f038680fa15f7
#   Line 52167: Secret Access Key - ntGmoWSo8b3Bv5CoWVPLW2k4jKiAP9QBjxYw/vie
#   Line 52186: Secret Access Key - app/dpdservicioexpress/modulodiaperturac
#   Line 52196: Secret Access Key - IwAR15AI2VSImLy7qjcNh1THPSSstq1yuPt6JN07
#   Line 52200: Secret Access Key - com/t/43431940/1624857538/56733586/0/109
#   Line 52206: Secret Access Key - tspjBcfthkB6Bjh3c1jM1IAXgi6FTXC5XBQRK8n5
#   Line 52206: Secret Access Key - gz3MlSzUUIHvfyG65rMQvbklb9Rmw4mo4yEPp8Sx
#   Line 52206: Secret Access Key - LbHBX1q2rpRr2EWi2VfpNfzkT20ztdG67DaSvdu2
#   Line 52223: Secret Access Key - 3zatkz/lixABy8N/oawo/nQGekMlRY4/QXJJbnZv
#   Line 52300: Secret Access Key - ri4N/weg/X37pnVBMkp/aXZhLmV4cGlyYXRpb24u
#   Line 52310: Secret Access Key - com/AAQkAGM3ZTM2ODcyLTAwZGMtNDk3NS05ZjUx
#   Line 52310: Secret Access Key - LTIxZmYyYzNkNTExMgAQADpiToNHie1Hjl70QEB7
#   Line 52322: Secret Access Key - includes/js/tinymce/skins/lightgray/lala
#   Line 52381: Secret Access Key - 2096/cpsess6807296530/3rdparty/roundcube
#   Line 52382: Secret Access Key - 93b468fdf3284ff3f2c8f22a8a87cba95517d378
#   Line 52392: Secret Access Key - da69879c363b00ff3d9c6947e79fc6a6c96445fb
#   Line 52392: Secret Access Key - 688b20e03f87e53593d057ca0c503485b3725b65
#   Line 52392: Secret Access Key - 7e464ef1354c4c3aea489232eeee7a3610d56dc3
#   Line 52392: Secret Access Key - 80e4737ca86d394363ded1b7bfc6b6f66b98d52e
#   Line 52397: Secret Access Key - 0f95c59a30af1e3a152874bd1ed8389e360301a1
#   Line 52443: Secret Access Key - R0Ern7crtrRkKtdQQ6UzVeARmEidPgRwVUEd9lf7
#   Line 52446: Secret Access Key - 0x2C0d9305a9779dfBD86Ffd49468E021E013E3c
#   Line 52457: Secret Access Key - com/view/messageriehtlmxccvsdfvf/accueil
#   Line 52476: Secret Access Key - mCATEkfgQezESxEXgycUHcIiuVkOsBQPbK2TYvcV
#   Line 52477: Secret Access Key - 4nuqfkPR50ovduwcc6CRgJ3t1D7E3X6nqoY34iMd
#   Line 52483: Secret Access Key - com/view/mailyahooservicesverifynow/home
#   Line 52487: Secret Access Key - RjZV6KIBAodQD25NUCsLBHWwcOfNMqmRk9Faoliz
#   Line 52487: Secret Access Key - xqcW1kLAo5fqCIhcuVgANfmeN4mcUArxbQxxSqmz
#   Line 52538: Secret Access Key - com/view/banquepostalebanqueetassurance/
#   Line 52542: Secret Access Key - content/plugins/gravityforms/includes/ht
#   Line 52682: Secret Access Key - TDASqlURFRQMjZXNEYxN0g3VExUTFVZQ0MzTU9FM
#   Line 52694: Secret Access Key - 1vTh3iya0ov7P49Rk9eJOZGqnUEUk8FNa2mkY389
#   Line 52694: Secret Access Key - heRtlwx4MNOyHl1MlhnWBZ8sxnsqTk8i5uySMQ68
#   Line 52701: Secret Access Key - net/obj/QkMyMThBNjg0RjJCRjg2Njc3OEM6YWY1
#   Line 52701: Secret Access Key - ZDcwYjhhODdhZmQwZDgyZTdkOTUyMDlkY2YzODY6
#   Line 52727: Secret Access Key - com/view/etyajdnxnskoeprlwyaxbdhfkrituy/
#   Line 52736: Secret Access Key - c11c0a637b94/9ddb3753cb700b0c86a78176be7
#   Line 52738: Secret Access Key - com/view/btcloudpaymentinvoice202000/htt
#   Line 52747: Secret Access Key - uaxi97dtneh142s40xq3x54he4jodvqs0vr7bvud
#   Line 52753: Secret Access Key - com/view/espacemessagerieorangesms/accue
#   Line 52759: Secret Access Key - 2096/cpsess7481100069/3rdparty/roundcube
#   Line 52761: Secret Access Key - cdf6e4054e1d/02a9fa6bd051dc6b4581ee3b617
#   Line 52769: Secret Access Key - com/appspotv450i7r8h9vf9y6yt8uiuft58f7uf
#   Line 52769: Secret Access Key - com/appspotv450i7r8h9vf9y6yt8uiuft58f7uf
#   Line 52773: Secret Access Key - ThG5XVUODNBWTVYTzhWWDNCTkNVOVo4TldCTExMV
#   Line 52812: Secret Access Key - com/file/d/1robIOsANBh8Doqa7YUIeWn3Akz40
#   Line 52813: Secret Access Key - com/file/d/19zPw90jGON3J5mERXi1pauVKjDMx
#   Line 52814: Secret Access Key - com/file/d/1GINBNlpVt7kpfNog9A68fqmn7k3a
#   Line 52830: Secret Access Key - IA5UzzOn3iViKU4F3pXemYHHABfWkPDjiRPFTFEa
#   Line 52832: Secret Access Key - IA5UzzOn3iViKU4F3pXemYHHABfWkPDjiRPFTFEa
#
# ============================================================
# SECURITY WARNING: POTENTIAL AWS KEYS FOUND IN FILE!
# Storing AWS Access Keys and Secret Access Keys directly in files
# is a significant security risk. If this file is compromised,
# your AWS resources could be accessed by unauthorized individuals.
#
# Recommendations for Secure Key Management:
# - AWS Secrets Manager: Securely store, manage, and retrieve secrets.
# - AWS Systems Manager Parameter Store: Store configuration data and secrets securely.
# - Environment Variables: Use environment variables for credentials, but ensure
#   they are managed securely and not exposed (e.g., in logs).
# - IAM Roles: Assign IAM roles to your EC2 instances or other AWS services
#   instead of embedding keys directly in applications or configuration files.
#
# It is highly recommended to rotate your keys immediately if they have
# been exposed and adopt a more secure method for credential management.
# ============================================================
#
# Successfully saved modified file: /content/online-valid_1_redacted.txt

# %%
from google.colab import files

files.download('/content/online-valid_1_redacted.txt')

# %%
import os

input_redacted_txt_path = '/content/online-valid_1_redacted.txt'
output_csv_path = '/content/online-valid_1_redacted.csv'

try:
    # Read the content from the redacted text file
    with open(input_redacted_txt_path, 'r') as infile:
        redacted_content = infile.readlines()

    # Write the content to a new file with a .csv extension
    with open(output_csv_path, 'w') as outfile:
        outfile.writelines(redacted_content)

    print(f"Content from '{input_redacted_txt_path}' saved to '{output_csv_path}' as a CSV file.")

except FileNotFoundError:
    print(f"Error: Input redacted file not found at {input_redacted_txt_path}")
except Exception as e:
    print(f"An error occurred while creating the CSV file: {e}")
# Out:
# Content from '/content/online-valid_1_redacted.txt' saved to '/content/online-valid_1_redacted.csv' as a CSV file.

# %%
from google.colab import files

# Download the newly created CSV file
files.download('/content/online-valid_1_redacted.csv')
